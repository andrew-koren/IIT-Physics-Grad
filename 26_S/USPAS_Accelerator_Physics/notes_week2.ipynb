# %% [markdown]
# ## Lecture Schedule
# The topics of each planned lecture are outlined below. This schedule is subject to change.
#
# <!-- Monday July 13
# - AM Lecture 1 ‘Relativity, EM Forces - Historical Introduction’ - Doug
# - PM Lecture 2 ‘Transverse linear betatron motion and focusing’ - Sami
# - (Pset 1 assigned)
#
# Tuesday July 14
# - AM Lecture 3 ‘Linear Optics’ - Sami
# - PM Lecture 4 ‘Phase Stability, Synchrotron Motion’ - Doug
# - (Pset 2 assigned)
#
# Wednesday July 15
# - AM Lecture 5 'Emittance, linear magnet errors, and dispersion' - Sami
# - PM Lecture 6 ‘Synchrotron Radiation’ - Doug
# - (Pset 3 assigned)
#
# Thursday July 16
# - AM Lecture 7 ‘Chromaticity, sextupoles, and magnet design’ - Sami
# - PM Lecture 8 ‘Radiation Distributions / Damping’ - Doug
# - (Pset 4 assigned)
#
# Friday July 17
# - Fri AM Lecture 9 Guest lecture on FELs - River Robles
# - Fri PM Midterm Exam
#
# - No pset assigned or due over the weekend. -->
#
# Monday July 20
# - AM Lecture 10 ‘Fundamentals of RF Cavities’ - Sami
# - PM Lecture 11 ‘Particle Acceleration / Linacs’  - Wei-Hou
# - (Pset 5 assigned)
#
# Tuesday July 21
# - AM Lecture 12 ‘Linacs - II / Linacs and Applications’ - Wei-Hou
# - PM Lecture 13 ‘Particle sources’ - Sami
# - (Pset 6 assigned)
#
# Wednesday July 22
# - AM Lecture 14 Guest lecture on PWA + TA Lecture (Patrick, cavities)
# - PM Lecture 15 ‘High Brightness’ - Wei-Hou, + TA Lecture (Parker, instrumentation/protons)
# - (Pset 7 assigned)
#
# Thursday July 23
# - AM Lecture 16 ‘Emittance exchange’ - Emilio, + TA Lecture (Peter, colliders)
# - PM Lecture 17 'Radiation crash course' - Sami
# - (Optional review pset 8 assigned)
#
# Friday July 24
# - AM Final Exam

# %% [markdown]
# $$
# \def\l{\left}\def\r{\right}
# \def\vn{\vec{\nabla}}
# $$

# %% [markdown]
# ## Lecture 10: Fundamentals of RF Cavities
#
# Note Helmut uses $\mu_0, \epsilon_0 = 1$. Seeh Helmut 18
#
# $$
# \begin{gathered}
#     \vec D = \epsilon \vec E,
# \qquad
#     \vec B = \mu \vec H
# \end{gathered}
# $$Source free region / vacuum
#
# $$
# \begin{darray}{cc}
#     E = E_0 e^{i\omega t},
# &   \vec J = 0,
# \\  \vec D = \epsilon_0 \vec E,
# &   \vec B = \mu_0 \vec H,
# \\  \vec \nabla \cdot \vec E = 0,
# &   \vec \nabla \cdot \vec B = 0,
# \\  \vec \nabla \times \vec H = i\omega \epsilon_0 \vec E,
# &   \vec \nabla \times \vec E = - i \omega \mu_0 \vec H,
# \end{darray}
#
# $$
#
# Curl to get wave equations.
#
# $$
# \begin{gathered}
#     \vn \times \l( \vn \times \vec A \r) = \vn\l(\vn\cdot\vec A\r) - \nabla^2\vec A
# \\  \nabla^2 \vec H = -\epsilon_0\mu_0 \omega^2 {\partial^2 \vec H \over \partial t^2}
# \\  \nabla^2 f = {1 \over V^2}{\partial^2 f \over \partial t^2}
# \\  \nabla^2 \vec E = - \epsilon_0 \mu_0 \omega^2 {\partial^2 \vec E \over \partial t^2}
# \end{gathered}
# $$
# velocity in vacuum $\vec E \perp \vec B \perp \vec k$. $V_{\text{ph}} = c = {1 \over \sqrt{\epsilon_0 \mu_0}}$.
# Wave number $k = {2\pi \over \lambda} = {\omega \over v}$.
# $$
# k^2 = \epsilon_r \mu_r {\omega^2 \over c^2} % helmut 18.4 should be k^2
# $$

# %% [markdown]
# Critcal: Boundary conditions. Faradys law forces parallel $\vec E$ and parallel $\vec H$ to the surface (divergence is charge) as well as perp $\vec B$ and $\vec H$
#
# Additional: metallic boundary
#
# $$
# \begin{gathered}
#     \sigma \rightarrow \infty,
# \\  \hat n \cdot \vec D = \rho_s,
# \\  \hat n \times \vec E = 0 \text{ no tangential } \vec E,
# \\  \hat n \cdot \vec B = 0,
# \\  \hat n \times \vec H = J_s \text{ surface current density}.
# \end{gathered}
# $$
#
# Guided waves.
#
# Eigenmodes are excited in waveguides / cavities.
# There is a cut-off minimum frequency.
# Propogation: Need real $k_z$ to propogate (instead of reflection & decay)
#
# $$
# \begin{align*}
#     k_z^2 &= k^2 - k_c^2 \ \leftarrow \text{ cutoff}
# \\  k_c^2 &= k_x^2 + k_y^2
# \end{align*}
# $$
#
# Real for $k_c = {\omega_c \over c}$. 6 eqns used to get modes equations.
# Lossy media hase complex propogation $\gamma = \alpha$ attenuation constant + $i \beta$ phase constant
#
# $$
# \begin{gathered}
# \gamma = i\omega \sqrt{\mu \epsilon \l(1 - {\sigma \over \omega \epsilon}\r) } \text{ bulk solution}
# \end{gathered}
# $$
# Modes are defined by how many times a flip occurs. $0$ is no oscillations $1$ is one oscillation (zero, positive, zero).
#
# How do you make fiber plots?
#
# Dispersion relation: guided wave phase velocity $v_{\text{ph}} \neq c$
#
# $$
# \begin{gathered}
#     v_{\text{ph}} = {\omega \over k_z},
# \quad
#     k_c = {\omega_c \over c},
# \\  k_z^2 = k^2 - k_c^2,
# \Rightarrow
#     k_z^2 = {\omega^2 \over v_\text{ph}^2} = {\omega^2 - \omega_c^2 \over c^2},
# \\  v_{\text{ph}} = {c^2 \omega^2 \over \omega^2 - \omega_c^2}.
#
# \end{gathered}
# $$
#
# The group velocity must be slower than the speed of light
#
# $$
#     v_{\text{g}} = {d \omega \over dk_z} < c.
# $$
#
# Sami worked on backward wave oscillator.0

# %% [markdown]
# Cavities. Magnetic and electric field are offset by 90 degrees instead of inline.
#
# $$
# \begin{gathered}
# f_{mnl} = {c \over 2\pi \sqrt{\mu_r \epsilon_r}} \sqrt{\l(p_{mn} \over a\r)^2 + \l(l \pi \over d\r)^2},
# \text{ pillbox}
# \\[1em] \begin{darray}{cc}
#     Q_0 = {\omega_0 U \over P},
# &   U_e = {\epsilon \over 4} \int_V \vec E \cdot \vec E^* ,
# \\[1em]  U_m = {\mu \over 4} \int_V \vec H \cdot \vec H^* dv,
# &   P = {R_{\text{surf}} \over 2} \int_S \l|H_t\r|^2 dS,
# \\[1em]  R_\text{surf} = {1 \over \sigma \delta_s},
# &   \delta_s = \sqrt{2 \over \omega \mu \sigma}.
# \end{darray}
# \end{gathered}
# $$ wahoo
#
# Loaded quality $Q_L = {\omega_0 \over \Delta \omega} = {Q_0 \over 1 + \beta_c}$ with $\beta_c$ coupling coefficient

# %% [markdown]
# ----

# %% [markdown]
# Accelerator cavities - TM010
#
# Helmut 18
#
# $$
# \begin{gathered}
#     E_z = E_{z_0} \sin \l(\omega {z \over v} + \delta \r) % field seen by particle
# \\  \Delta E_{\text{kin}} = |g| \int E_z dz % energy gain
# \\  \begin{align*}
#     V_{\text{RF}}&= E_{z_0} d % maximal value
#               \\ &= E_{\text{010}} d
# \end{align*}
# \end{gathered}
# $$
# For this mode,
# $$
# \begin{align*}
#     \Delta E_{\text{kin}}&= |q|V_{\text{RF}} \text{sinc}(\omega d / 2 v)
# \\                       &= |q|V_{\text{cycle}}
# \end{align*}
# $$
# Or define transit-time factor which scales based off RF phase
# $$
# \begin{gathered}
# T = \text{sinc}(\omega d / 2 v)
# \\  \Delta E_{\text{kin}} = |q|V_{\text{RF}} T
# \end{gathered}
# $$
#
# Power loss engineering
# $$
#     P_{\text{cycle}} = {1 \over 4} \epsilon_0 \omega \delta_s E_{010}^2 \int_S J_1^2\l(2.405 {r \over a}\r) ds
# \\  \boxed{
#             P_{\text{cycle}}
#         =   {1 \over 2} \pi \epsilon_0 \omega \delta_s
#             V_{\text{RF}}^2 \underbrace{J_1^2(2.405)}_{=0.519^2}
#             {a(a+d) \over d^2}
# }
# $$
#
# Stored energy engineering
#
# $$
# U_e = {1 \over 2} \epsilon_0 E_{010}^2 d a^2 J_1^2(2.405)
# $$
#
# Fill time (see srf bible)
#
# $$
# t_F = {2 Q_L \over \omega} = {2 Q_0 \over (1 + \beta_c) \omega}
# $$

# %% [markdown]
# Shunt impedance $R_{\text{shunt}}$ ($R_s$ in helmut, see 18.2 (pg 621))
#
# Breakdown/field emission engineering $f\l[\text{MHz}\r] = 1.64 E_K^2 e^{-8.5/E_K}$
#
# [2022 USPAS SRF Class](https://sites.google.com/view/uspas2022-rf-superconductivity/home)
#
# [NCRF](https://www.osti.gov/servlets/purl/1441166)
#
# Cavity tuning is also there

# %% [markdown]
# ## Particle Acceleration / Linacs
#
# Expanding on previous lecture, energy gain across a RF voltage gap
#
# $$
# \begin{gathered}
#     E_z(s,t) = E(s) \cos(\omega t + \phi_s + \Delta \phi)
# \\  \Delta U = q \int_{-L/2}^{L/2} E(s) \cos(\omega t(s)+\phi_s + \Delta \phi) ds
# % \\  \text{note } t(s)
# \\  \Delta U = qV_0 T \cos \l(\phi_s + \Delta \phi \r)
#              - \underbrace{\cancel{q\sin(\phi_s+\Delta \phi)\int E(s) \sin(\omega t)ds}}_{\text{even assumption}}
# \\  T = \frac{\int_{-L/2}^{L/2} E(s) \cos (\omega t(s)) ds}{\int_{-L/2}^{L/2} E(s) ds}
# \end{gathered}
# $$
#
# Crossing out the sine term requires constant velocity $t = s/v$, what would that correction look like?
#
# $\pi$-mode ${\omega L \over v} = \pi$, or $L= \beta \lambda /2$.

# %% [markdown]
# EOMs. Refer to lecture notes for equations
#
# - we find EOMs by starting with rf cavity energy gain and phase advance equations
# - separatrix via $H(\phi,\Delta W) = H_c$
# - Rewrite HOMs as SHO
#
# Karen: Why is the phase offset the same for $\Delta W$ and $\Delta \phi$? One is sine and the other is cosine.
#
# - Write adiabatic damping $\Delta \hat W = {k_s \over A} \Delta \hat \phi$ (amplitude hats)
# - Action $J={1 \over 2} \Delta \hat \phi \Delta \hat W$ is constant
# - Turns out $A/B \propto 1/\beta_s^3 \phi_s^3 \rightarrow $ energy variation grows and phase variation shrinks
# -----
#
# - cosine acceleration & stability for $-\pi/2 < \phi_s < 0$

# %% [markdown]
# RF defocusing (slide 12)
#
# The beam is longitudinally compressed but spreads in the transverse.
#
# - Compute $B_\theta$ from $\vn \times \vec B$
# - Compute $F_r$ from $E_r-v_zB_\theta$ (assume synchronous $v_z=\beta_sc$)
# - Compute $\Delta p_r$ by integrating, substititute time with constant velocity assumption
#     - takes a while to manage $t(s)$ in the derivatives
