# %% [markdown]
# # 501 HW 6 - Andrew Koren

# %% [markdown]
# ### 3.3.6

# %% [markdown]
# Following through the derivations in section 3.3, we arrive at
# $$
#       u_{m,n}(r,\phi,t)
#     = J_m \left(r x_n^{(m)} \over a \right)
#       \left(
#         A_{mn} \cos(m\phi)
#       + B_{mn} \sin(m\phi)
#     \right)
#       \left(
#         C_{mn} \cos\left(ct x_n^{(m)}\over a \right)
#       + D_{mn} \sin\left(ct x_n^{(m)}\over a \right)
#     \right).
# $$
#
# Our initial conditions $u_1$ give us
# $$
#       u_1(r,\phi)
#     = u'(r,\phi,0)
#     = 0
# \\  = \sum_{m,n} u_{m,n}(r,\phi,t)
#     = J_m \left(r x_n^{(m)} \over a \right)
#       \left(
#         A_{mn} \cos(m\phi)
#       + B_{mn} \sin(m\phi)
#     \right)
#       \left(
#         C_{mn}
#     \right)
# $$
# allowing us to set $C_{mn}=0$, and for $u_2$
# $$
# \\[1em]
#       u_2(r,\phi)
#     = u'(r,\phi,0)
#     = 1
# \\  = \sum_{m,n} J_m \left(r x_n^{(m)} \over a \right)
#       \left(
#         A_{mn} \cos(m\phi)
#       + B_{mn} \sin(m\phi)
#     \right)
#       \left(
#         D_{mn} {c x_n^{(m)}\over a}
#     \right)
# $$
#
# we can absorb $D_{mn}$ into the other terms
#
# $$
#       \bar A_{mn} = A_{mn}D_{mn} {c x_n^{(m)}\over a}
# \qquad\bar B_{mn} = B_{mn}D_{mn} {c x_n^{(m)}\over a}
# \\  \begin{align*}
#     u_2(r,\phi)
#    &= \sum_{m,n} J_m \left(r x_n^{(m)} \over a \right)
#       \left(
#         \bar A_{mn} \cos(m\phi)
#       + \bar B_{mn} \sin(m\phi)
#     \right)
# \\ &= \sum_{m=0}^\infty \cos(m\phi)
#       \sum_{n=1}^\infty \bar A_{mn} J_m \left(r x_n^{(m)} \over a \right)
#     + \sum_{m=1}^\infty \sin(m\phi)
#       \sum_{n=1}^\infty \bar B_{mn} J_m \left(r x_n^{(m)} \over a \right).
# \end{align*}
#
# $$
# To get rid of the angular component notice that $m$ is in the sine/cosine portions, so forcing $B \rightarrow 0$ and $A_{m>0} \rightarrow 0 $ leaves us with a pure radial function
#
# $$
# \\  =
#       \sum_{n=1}^\infty \bar A_{0n} J_0 \left(r x_n \over a \right) = 1.
# $$
# The textbook actually gives us this expansion in Sec. 3.2
# $$
#     J_m(x) = 0  \rightarrow \beta = 0
# \\  1 = 2 \sum_{n=1}^{\infty} {J_0(x x_n) \over x_n J_1 (x_n)}
#       =   \sum_{n=1}^{\infty} {2 \over x_n J_1 (x_n)} J_0 \left(r x_n \over a\right)
# \\[0.5em] \bar A_{0n} = {2 \over x_n J_1 (x_n)}.
# $$
# Yielding our final wavefunction
# $$
#       u(r,\phi,t)
#     = \sum_{n=1}^\infty {2 \over x_n J_1 (x_n)}
#     J_0 \left(r x_n \over a \right)
#     \sin\left(ct x_n\over a \right)
#
# $$
#
# <!-- $$
#       \langle f(x), J_m(x x_n) \rangle
#     = A_n \| J_m(x x_n) \|^2
# $$
# but what is the choice of $m$? -->
# <!--
# $$
#       u(r,\phi,0)
#     = 1
#     = J_m
# $$ -->
#
# <!-- We are solving
# $$
# \def\d#1#2{\frac{\partial #1}{\partial #2}}
#     \d{^2 u}{t^2} - c^2\nabla^2 u = 0
# $$
# with
# $$
#     \nabla^2u
#     =              \d{^2 U}{r^2}
#     + {1 \over r}  \d{   U}{r}
#     + {1 \over r^2}\d{^2 U}{\phi^2}
#     +              \d{^2 U}{z^2}
# \\[1em]
#     u(r,\phi, t) = R(r)\Phi(\phi)T(t)
# $$
# yielding
# $$
# \\    \underbrace{
#       \frac{1}{c^2}\frac{T''}{T}
#     }_{ \lambda}
#     - \underbrace{ \frac{R''+\frac{1}{r}R'}{R}
#     }_{ \lambda + \mu}
#     - \underbrace{
#       \frac{1}{r^2}\frac{\Phi''}{\Phi}
#     }_{\mu}
#     =0
# \\[0.5em]
#     T'' + \lambda c^2 T = 0
# \\  \Phi'' + \mu \Phi= 0
# $$ -->

# %% [markdown]
# ### 3.3.7

# %% [markdown]
# Again $C_{mn}=0$ and there is no angular component, yielding
#
# $$
#       u_2(r,\phi)
#     = \sum_{n=1}^\infty \bar A_{0n} J_0 \left(r x_n \over a \right)
#     = a^2 - r^2.
# $$
# I would go ahead and compute the expansion myself, but I've forgotten all the identities for $J_n$, so I'll just use the book's hard work from example 3.2.6 instead.
#
# $$
#     1 - x^2 = 8 \sum_{n=1}^{\infty} \frac{ J_0(x x_n)}{x^3_n J_1(x_n)}
# \\  a^2 - r^2 = \sum_{n=1}^{\infty} \frac{ 8 a^2}{x^3_n J_1(x_n)} J_0\left(rx_n\over a\right)
# \\  \bar A_{0n} = \frac{ 8 a^2}{x^3_n J_1(x_n)}
# \\    u(r,\phi,t)
#     = \sum_{n=1}^\infty \frac{ 8 a^2}{x^3_n J_1(x_n)}
#     J_0 \left(r x_n \over a \right)
#     \sin\left(ct x_n\over a \right)
#
# $$

# %% [markdown]
# ### 3.4.1

# %% [markdown]
# Like in the last homework, our answer will have no $z$-dependence since it is unbounded.
#
# In section 3.4.2 of the book we find
# $$
# u(r,\phi,t) = \sum_{m,n} J_m \left(r x_n^{(m)} \over r_{\text{max}}\right)
#     \left(
#           A_{mn} \cos(m \phi)
#         + B_{mn} \sin(m \phi)
#     \right)
#     \exp \left[
#         -\left(x_n^{(m)}\right)^2 Kt \over r_{\text{max}}^2
#     \right]
# $$
# for a zero steady-state solution. Without an angular component to $u(\rho,\phi,0)$, we set $A_{m>0}=0$ and $B_{mn}=0$, yielding
#
# $$
# u(r,\phi,t) = \sum_{n=1}^{\infty} A_n J_0 \left(r x_n \over r_{\text{max}}\right)
#     \exp \left[
#         -x_n^2 Kt \over r_{\text{max}}^2
#     \right].
# $$
# Looks familiar? Applying our expansion from 3.3.7, we know $A_n = \frac{ 8 r_{\text{max}}^2}{x^3_n J_1(x_n)}$
# $$
# u(r,\phi,t) = \sum_{n=1}^{\infty} \frac{ 8 r_{\text{max}}^2}{x^3_n J_1(x_n)}J_0 \left(r x_n \over r_{\text{max}}\right)
#     \exp \left[
#         -x_n^2 Kt \over r_{\text{max}}^2
#     \right].
#
# $$

# %% [markdown]
# ### 3.4.2

# %% [markdown]
# Now, the steady-state solution is $U(r,\phi)=1$. We'll use follow example 3.4.3 from the book and find
# $$
#     v(r,\phi,t) = u(r,\phi,t) - U(r)
# \\  U_t(r) = k\nabla^2 U(r) = 0
# \\  v(r,\phi,0) = u(r,\phi,0) - U(r) = -1
# \\  v(r_{\text{max}},\phi,t) = 0.
# $$
# Now the solution is easy. The boundary conditions match our earlier problem, and we already have an expansion for $1$ in terms of $J_0(x x_n)$:
#
# $$
#     v(r,\phi,t) = \sum_{n=1}^{\infty} A_n J_0 \left( r x_n \over r_{\text{max}}\right) \exp \left[-x_n^2 K t \over r_{\text{max}}^2 \right],
#     \qquad  A_n = -{2 \over x_n J_1(x_n)}
# \\  u(r,\phi,t)
#     = -2 \sum_{n=1}^{\infty} {J_0 \left( r x_n \over r_{\text{max}}\right) \over x_n J_1(x_n)}
#         \exp \left[-x_n^2 K t \over r_{\text{max}}^2 \right]
#     + 1.
# $$
# Ripping directly from the book, the relaxation time depends on the first zero $J_0(x_1)=0$
# $$
# \tau = {r_{\text{max}}^2 \over x_1^2 K}.
# $$
# (note this isn't a mysterious constant, it's just the slowest $e^{{- {t / \tau}}}$)

# %% [markdown]
# ### 3.5.1

# %% [markdown]
# According to the book this is a Type III boundary.
#
# $$
#       u(r, \phi, z)
#     = \sum_{m,n} J_m\left( r x_n^{(m)} \over r_{\text{max}}\right)
#       \left(
#         A_m \cos(m\phi) + B_m \sin(m\phi)
#       \right)
#       \sinh\left( x_n^{(m)}(L-z) \over r_{\text{max}}\right)
# $$
# We'll use the normal trick of only using $A_1$ to get rid of angular dependence
#
# $$
#       u(r, \phi, z)
#     = \sum_{n=1}^{\infty}
#       A_n
#       J_0\left( r x_n \over r_{\text{max}}\right)
#       \sinh\left( x_n(L-z) \over r_{\text{max}}\right)
# $$
# At the moment, we have $u(r,\phi,L) = 0$, so let's check out $u(z=0)$
#
# $$
#       u(r,\phi,0)
#     = \sum_{n=1}^{\infty} A_n J_0\left( r x_n \over r_{\text{max}}\right)
#       \sinh\left( x_n L \over r_{\text{max}}\right)
#     = 1
# $$
# Fortunately, we don't have to do anything special for this expansion, just rescale our expansion for $1$ as
# $$
#       1
#     = \sum_{n=1}^{\infty} {2 \over x_n J_1 (x_n)} J_0 \left(r x_n \over a\right)
# \\
#     = \sum_{n=1}^{\infty} {2 \sinh\left( x_n L \over r_{\text{max}}\right) \over x_n J_1 (x_n)}
#     J_0 \left(r x_n \over a\right)
#     \sinh\left( x_n L \over r_{\text{max}}\right)
# \\  A_n = {2 \sinh\left( x_n L \over r_{\text{max}}\right) \over x_n J_1 (x_n)}
#     %   A_n J_0\left( r x_n \over r_{\text{max}}\right)
#     % = {1 \over \sinh\left( x_n L \over r_{\text{max}}\right) }
# $$
# yielding the final expression
# $$
#       u(r, \phi, z)
#     = \sum_{n=1}^{\infty}
#       {2 \sinh\left( x_n L \over r_{\text{max}}\right) \over x_n J_1 (x_n)}
#       J_0\left( r x_n \over r_{\text{max}}\right)
#       \sinh\left( x_n(L-z) \over r_{\text{max}}\right)
#
# $$
#
# <!-- The laplace equation with $u(r,\phi,z) = R(r)\Phi(\phi)Z(z)$ gives us
#
# $$
#       {R'' + (1/r)R' \over R}
#     + {(1/r^2)\Phi'' \over \Phi}
#     + {Z''           \over Z}
#     = 0
# $$
# Since $Z(0)=1$, we'' have $Z$ exponential and $\Phi$ periodic, so the basic form of each component is something like
#
# $$
# \\  R(r)        = A J_m\left( r x_{n}^{(m)} \over r_{\text{max}}\right)
# \\  \Phi(\phi)  = A \cos (m\phi) + B \sin (m\phi)
# \\  Z(z)        = A \cosh(z \dots) + B \sinh(z \dots)
# $$
#  -->

# %% [markdown]
# According to the book this is a Type III boundary.
#
# $$
#       u(r, \phi, z)
#     = \sum_{m,n} J_m\left( r x_n^{(m)} \over r_{\text{max}}\right)
#       \left(
#         A_m \cos(m\phi) + B_m \sin(m\phi)
#       \right)
#       \sinh\left( x_n^{(m)}(L-z) \over r_{\text{max}}\right)
# $$
# We'll use the normal trick of only using $A_1$ to get rid of angular dependence
#
# $$
#       u(r, \phi, z)
#     = \sum_{n=1}^{\infty}
#       A_n
#       J_0\left( r x_n \over r_{\text{max}}\right)
#       \sinh\left( x_n(L-z) \over r_{\text{max}}\right)
# $$
# At the moment, we have $u(r,\phi,L) = 0$, so let's check out $u(z=0)$
#
# $$
#       u(r,\phi,0)
#     = \sum_{n=1}^{\infty} A_n J_0\left( r x_n \over r_{\text{max}}\right)
#       \sinh\left( x_n L \over r_{\text{max}}\right)
#     = 1
# $$
# Fortunately, we don't have to do anything special for this expansion, just rescale our expansion for $1$ as
# $$
#       1
#     = \sum_{n=1}^{\infty} {2 \over x_n J_1 (x_n)} J_0 \left(r x_n \over a\right)
# \\
#     = \sum_{n=1}^{\infty} {2 \sinh\left( x_n L \over r_{\text{max}}\right) \over x_n J_1 (x_n)}
#     J_0 \left(r x_n \over a\right)
#     \sinh\left( x_n L \over r_{\text{max}}\right)
# \\  A_n = {2 \sinh\left( x_n L \over r_{\text{max}}\right) \over x_n J_1 (x_n)}
#     %   A_n J_0\left( r x_n \over r_{\text{max}}\right)
#     % = {1 \over \sinh\left( x_n L \over r_{\text{max}}\right) }
# $$
# yielding the final expression
# $$
#       u(r, \phi, z)
#     = \sum_{n=1}^{\infty}
#       {2 \sinh\left( x_n L \over r_{\text{max}}\right) \over x_n J_1 (x_n)}
#       J_0\left( r x_n \over r_{\text{max}}\right)
#       \sinh\left( x_n(L-z) \over r_{\text{max}}\right)
#
# $$
#
# <!-- The laplace equation with $u(r,\phi,z) = R(r)\Phi(\phi)Z(z)$ gives us
#
# $$
#       {R'' + (1/r)R' \over R}
#     + {(1/r^2)\Phi'' \over \Phi}
#     + {Z''           \over Z}
#     = 0
# $$
# Since $Z(0)=1$, we'' have $Z$ exponential and $\Phi$ periodic, so the basic form of each component is something like
#
# $$
# \\  R(r)        = A J_m\left( r x_{n}^{(m)} \over r_{\text{max}}\right)
# \\  \Phi(\phi)  = A \cos (m\phi) + B \sin (m\phi)
# \\  Z(z)        = A \cosh(z \dots) + B \sinh(z \dots)
# $$
#  -->

# %% [markdown]
# ### 3.5.2

# %% [markdown]
# The book explains that any solution that exists can be decomposed into a sum of each of th ethree types of solutions. In this case, the solution is just a linear combination of the previous problem and type II boundary conditions
# $$
# u = T_2 u_{II} + T_1 u_{III}
# $$
# (where $u_{II}$ solves for when $u(r,\phi,L)=1$).
#
# So, we need only find $u_{II}$. We'll skip along to after dealing with the $\phi$ component.
#
# $$
# u_{II}(r,\phi,z)=\sum_{n=1}^{\infty}
#       A_n
#       J_0\left( r x_n \over r_{\text{max}}\right)
#       \sinh\left( x_nz  \over r_{\text{max}}\right)
# \\
# u_{II}(r,\phi,L)=\sum_{n=1}^{\infty}
#       A_n
#       J_0\left( r x_n \over r_{\text{max}}\right)
#       \sinh\left( x_nL  \over r_{\text{max}}\right)
#
# $$
# and use the same trick as previously
# $$
#           1
#     = \sum_{n=1}^{\infty} {2 \over x_n J_1 (x_n)} J_0 \left(r x_n \over a\right)
# \\
#     = \sum_{n=1}^{\infty} {2 \sinh\left( x_n L \over r_{\text{max}}\right) \over x_n J_1 (x_n)}
#     J_0 \left(r x_n \over a\right)
#     \sinh\left( x_n L \over r_{\text{max}}\right).
# $$
# That's exactly the same $A_n$ as before, so
# $$
#       u_{II}(r,\phi,z)
#     = \sum_{n=1}^{\infty}
#       {2 \sinh\left( x_n L \over r_{\text{max}}\right) \over x_n J_1 (x_n)}
#       J_0\left( r x_n \over r_{\text{max}}\right)
#       \sinh\left( x_nz  \over r_{\text{max}}\right)
# \\[1em]
#     \begin{align*}
#     u(r,\phi,z)
#     = T_1&\sum_{n=1}^{\infty}
#       {2 \sinh\left( x_n L \over r_{\text{max}}\right) \over x_n J_1 (x_n)}
#       J_0\left( r x_n \over r_{\text{max}}\right)
#       \sinh\left( x_n(L-z) \over r_{\text{max}}\right)
# \\  + T_2&\sum_{n=1}^{\infty}
#       {2 \sinh\left( x_n L \over r_{\text{max}}\right) \over x_n J_1 (x_n)}
#       J_0\left( r x_n \over r_{\text{max}}\right)
#       \sinh\left( x_nz  \over r_{\text{max}}\right)
# \\  =&\sum_{n=1}^{\infty} {2 \sinh\left( x_n L \over r_{\text{max}}\right) \over x_n J_1 (x_n)}
#       J_0\left( r x_n \over r_{\text{max}}\right)
#     \left(
#         T_1 \sinh\left( x_n(L-z) \over r_{\text{max}}\right)
#     +   T_2 \sinh\left( x_nz  \over r_{\text{max}}\right)
#
#     \right).
#     \end{align*}
# $$

# %% [markdown]
# The book explains that any solution that exists can be decomposed into a sum of each of th ethree types of solutions. In this case, the solution is just a linear combination of the previous problem and type II boundary conditions
# $$
# u = T_2 u_{II} + T_1 u_{III}
# $$
# (where $u_{II}$ solves for when $u(r,\phi,L)=1$).
#
# So, we need only find $u_{II}$. We'll skip along to after dealing with the $\phi$ component.
#
# $$
# u_{II}(r,\phi,z)=\sum_{n=1}^{\infty}
#       A_n
#       J_0\left( r x_n \over r_{\text{max}}\right)
#       \sinh\left( x_nz  \over r_{\text{max}}\right)
# \\
# u_{II}(r,\phi,L)=\sum_{n=1}^{\infty}
#       A_n
#       J_0\left( r x_n \over r_{\text{max}}\right)
#       \sinh\left( x_nL  \over r_{\text{max}}\right)
#
# $$
# and use the same trick as previously
# $$
#           1
#     = \sum_{n=1}^{\infty} {2 \over x_n J_1 (x_n)} J_0 \left(r x_n \over a\right)
# \\
#     = \sum_{n=1}^{\infty} {2 \sinh\left( x_n L \over r_{\text{max}}\right) \over x_n J_1 (x_n)}
#     J_0 \left(r x_n \over a\right)
#     \sinh\left( x_n L \over r_{\text{max}}\right).
# $$
# That's exactly the same $A_n$ as before, so
# $$
#       u_{II}(r,\phi,z)
#     = \sum_{n=1}^{\infty}
#       {2 \sinh\left( x_n L \over r_{\text{max}}\right) \over x_n J_1 (x_n)}
#       J_0\left( r x_n \over r_{\text{max}}\right)
#       \sinh\left( x_nz  \over r_{\text{max}}\right)
# \\[1em]
#     \begin{align*}
#     u(r,\phi,z)
#     = T_1&\sum_{n=1}^{\infty}
#       {2 \sinh\left( x_n L \over r_{\text{max}}\right) \over x_n J_1 (x_n)}
#       J_0\left( r x_n \over r_{\text{max}}\right)
#       \sinh\left( x_n(L-z) \over r_{\text{max}}\right)
# \\  + T_2&\sum_{n=1}^{\infty}
#       {2 \sinh\left( x_n L \over r_{\text{max}}\right) \over x_n J_1 (x_n)}
#       J_0\left( r x_n \over r_{\text{max}}\right)
#       \sinh\left( x_nz  \over r_{\text{max}}\right)
# \\  =&\sum_{n=1}^{\infty} {2 \sinh\left( x_n L \over r_{\text{max}}\right) \over x_n J_1 (x_n)}
#       J_0\left( r x_n \over r_{\text{max}}\right)
#     \left(
#         T_1 \sinh\left( x_n(L-z) \over r_{\text{max}}\right)
#     +   T_2 \sinh\left( x_nz  \over r_{\text{max}}\right)
#
#     \right).
#     \end{align*}
# $$

# %% [markdown]
# ### 3.5.4

# %% [markdown]
# We might be able to make this one out of the three solution types, but those are all optimized around $u=0$ not $u_z=0$. It'll be smarter to derive our own Neumann or Mixed case instead. From the laplace operator in cylinderical coordinates and separation, we have
#
# $$
#       {R'' + (1/r)R' \over R}
#     + {1 \over r^2} \underbrace{{\Phi'' \over \Phi}}_{-m^2}
#     +               \underbrace{Z''     \over Z    }_{-\lambda^2}
#     = 0
# \\  Z'' = - \lambda z
# \\  Z(z) = A \sin(\lambda z) + B \cos(\lambda z)
# \\  Z(0) = 0 \rightarrow B = 0
# \\  Z'(L) = 0
#     \rightarrow \lambda L = {(2n-1)\pi \over 2}
# \\  \rightarrow \lambda = {(2n-1)\pi \over 2L}
# \\  Z(z) = \sin \left((2n-1)\pi z \over 2L \right)
# \\  \Phi(\phi) = A \sin(m\phi) + B \cos(m\phi),
# $$
# which results in the modified bessel function
# $$
# R'' + {R' \over r} - \left( \left((2n-1)\pi \over 2L \right)^2 + {m^2\over r^2}\right) R = 0
# \\
# R(r) = I_m \left((2n-1)\pi r \over 2L \right)
# $$
#
# Giving us the perfect custom solution (after removing angular dependence)
#
# $$
# u(r,\phi,z) = \sum_{n=1}^{\infty}
#     A_n I_0
#     \left((2n-1)\pi r \over 2L \right)
#     \sin \left((2n-1)\pi z \over 2L \right)
# $$
# and, all we need is a sine expansion to get our boundary condition
# $$
# u(r_{\text{max}},\phi,z) = \sum_{n=1}^{\infty}
#     A_n
#     I_0 \left((2n-1)\pi r_{\text{max}} \over 2L \right)
#     \sin \left((2n-1)\pi z \over 2L \right)
# \\  = \sum_{n=1}^{\infty}
#     \bar{A}_n \sin \left((2n-1)\pi z \over 2L \right)
#     = 1
# $$
# where $\bar{A}_n = A_n I_0 \left((2n-1)\pi r_{\text{max}} \over 2L \right)$ to bundle up the constants. We actually did this expansion in homework 5
#
# $$
# \frac{\left\langle 1, \sin \left((2n-1)\pi z \over 2L \right) \right\rangle}
#      {\left\| \sin \left((2n-1)\pi z \over 2L \right) \right\|^2}
#     = {2 \over L} \int_{0}^L \sin \left((2n-1)\pi z \over 2L \right)
#     = {4 \over (2n-1)\pi}
#     = \bar{A}_n
# \\  A_n = {4 \over (2n-1)\pi I_0 \left((2n-1)\pi r_{\text{max}} \over 2L \right) }
# \\  u(r,\phi,z) = \sum_{n=1}^{\infty}
#     \frac{4 I_0 \left((2n-1)\pi r \over 2L \right)}{(2n-1)\pi I_0 \left((2n-1)\pi r_{\text{max}} \over 2L \right) }
#     \sin \left((2n-1)\pi z \over 2L \right)
# $$
# Or, more descriptively
# $$
# \\  \bar{A}_n = {2L \over \lambda_n}
# \qquad
#     u(r,\phi,z) = \sum_{n=1}^{\infty}
#     {2 L \over \lambda_n}
#     \frac{I_0 \left(\lambda_n r \right)}{ I_0 \left(\lambda_n r_{\text{max}} \right) }
#     \sin \left(\lambda_n z \right)
#
# $$

# %% [markdown]
# <!-- So, $u_z(L)=0$, doesn't that just mean $u(r,\phi,L)=f(r,\phi)$? I'm suprised this is fully defined. This problem is composed of a type I and type II solution.
#
# For the type I solution with no angular component:
#
# $$
#   u_I(r,\phi,z) = \sum_{k=1} A_k I_0 \left( k \pi r \over L \right)
#                   \sin\left( k \pi z \over L \right)
# \\    u_I(r_{\text{max}},\phi,z)
#     = \sum_{k=1}
#         A_k
#         I_0 \left( k \pi r_{\text{max}} \over L \right)
#         \sin\left( k \pi z \over L \right)
#     = 1
# $$
# Now, we need to find the expansion $\langle 1, \sin\left( k \pi z \over L \right) \rangle$ and rescale. As usual, we'll steal from the book rather than doing the integral.
#
# $$
# 1 = {4 \over \pi} \sum_{k\ \text{odd}} {\sin \left(k\pi z \over L\right) \over k}
# \\=               \sum_{k\ \text{odd}}
#     {4 I_0 \left( k \pi r_{\text{max}} \over L \right) \over k \pi}
#     I_0 \left( k \pi r_{\text{max}} \over L \right)
#     \sin \left(k\pi z \over L\right)
# \\=               \sum_{k=1}
#     {4 I_0 \left( (2k+1) \pi r_{\text{max}} \over L \right) \over (2k+1) \pi}
#     I_0 \left((2k+1) \pi r_{\text{max}} \over L \right)
#     \sin \left((2k+1)\pi z \over L\right)
# $$
# yielding
# $$
# u_I(r,\phi,z)
#     = \sum_{k=1}
#     {4 I_0 \left( (2k+1) \pi r_{\text{max}} \over L \right) \over (2k+1) \pi}
#     I_0 \left( (2k+1) \pi r \over L \right)
#     \sin\left( (2k+1) \pi z \over L \right)
# $$
# Actually, I'm not so sure how $u_{II}$ fits into this. Our $u_{I}$ solution garuntees $u_{I}(z=L)=0$, but what about $u_z$?
#
# $$
# {u_{I}}_z(z=L) = \sum_{k=1}
#     {4 I_0 \left( (2k+1) \pi r_{\text{max}} \over L \right) \over (2k+1) \pi}
#     I_0 \left( (2k+1) \pi r \over L \right)
#     {(2k+1) \pi \over L}
#     \cos\left( (2k+1) \pi \right)
# \\  = -\sum_{k=1}
#     {4 I_0 \left( (2k+1) \pi r_{\text{max}} \over L \right) \over (2k+1) \pi}
#     I_0 \left( (2k+1) \pi r \over L \right)
#     {(2k+1) \pi \over L}
# $$
# So we need $u_{II}$ to be the opposite of this. Still no angular dependence, so we can use the simplified version
#
#
# $$
# u_{II}(r,\phi,z)=\sum_{n=1}^{\infty}
#       A_n
#       J_0\left( r x_n \over r_{\text{max}}\right)
#       \sinh\left( x_nz  \over r_{\text{max}}\right)
# \\
# {u_{II}}_{z}(r,\phi,L)=\sum_{n=1}^{\infty}
#       A_n
#       J_0\left( r x_n \over r_{\text{max}}\right)
#       {x_n \over r_{\text{max}}} \cosh\left( x_n L \over r_{\text{max}}\right)
# \\ %= \bar{A}_n J_0\left( r x_n \over r_{\text{max}}\right)
# \\  = -{u_{I}}_z(z=L)
# $$
#
# Does that mean we have to find $I_0$ in terms of $J_0$? That's crazy -->

# %% [markdown]
# ### 3.5.5

# %% [markdown]
# That's not too bad. We'll just have to expand $z$ in terms of sine, which we've done many times
#
# Type I boundary without angular dependence
# $$
#   u(r,\phi,z) = \sum_{k=1}^{\infty} A_k I_0 \left( k \pi r \over L \right)
#                   \sin\left( k \pi z \over L \right)
# \\    u(r_{\text{max}},\phi,z)
#     = \sum_{k=1}^{\infty}
#         A_k
#         I_0 \left( k \pi r_{\text{max}} \over L \right)
#         \sin\left( k \pi z \over L \right)
#     = z
# \\    \bar{A}_k
#     = A_k I_0 \left( k \pi r_{\text{max}} \over L \right)
#     = {2 \over L} \left \langle z, \sin\left( k \pi z \over L \right) \right \rangle
#     = {2L \over \pi n}{(-1)^{n+1}}
# \\
#       A_k
#     = {2L \over \pi n}{(-1)^{n+1} \over I_0 \left( k \pi r_{\text{max}} \over L \right)}
# \\
#       u(r,\phi,z)
#     = \sum_{k=1}^{\infty} (-1)^{n+1}
#     {2L \over \pi n}{I_0 \left( k \pi r \over L \right) \over I_0 \left( k \pi r_{\text{max}} \over L \right)}
#
#     \sin\left( k \pi z \over L \right)
#
# $$

# %% [markdown]
# ### 4.1.14

# %% [markdown]
# This matches section 4.1.2 in the book, which derives the general solution as
#
# $$
# u(r,t) = {a \over r} \sum_{n=-\infty}^{\infty} \alpha_n e^{i \omega_n t}
#     \left(\frac
#     {e^{c_n(1+i)r}-e^{-c_n(1+i)r}}
#     {e^{c_n(1+i)a}-e^{-c_n(1+i)a}}
#     \right)
# $$
# where $c_n = \sqrt{n / K}$
#
#
#
# The boundary condition $u(a,t) = 3\cos(2t)$ can be written as
# $$
#       3 \cos(2t)
#     = {3 \over 2}\left(
#     e^{2i t} + e^{-2i t}
#     \right)
# \\
#     = \alpha_{1} e^{i \omega_{1} t } + \alpha_{-1} e^{i \omega_{-1} t }
# $$
# so the solution is just
# $$
#     u(r,t)
#     = {3a \over 2r}  \left(
#       e^{ 2i t}
#       \left(\frac
#         {e^{\sqrt{1 / k}(1+i)r}-e^{-\sqrt{1 / k}(1+i)r}}
#         {e^{\sqrt{1 / k}(1+i)a}-e^{-\sqrt{1 / k}(1+i)a}}
#       \right)
#     +
#       e^{-2i t}
#       \left(\frac
#         {e^{-\sqrt{1 / k}(1-i)r}-e^{\sqrt{1 / k}(1-i)r}}
#         {e^{-\sqrt{1 / k}(1-i)a}-e^{\sqrt{1 / k}(1-i)a}}
#       \right)
#     \right)
# % \\  = {3a \over 2r} e^{ 2i t}  \left(
# %         \frac
# %         {e^{ \sqrt{1 / k}(1+i)r}-e^{-\sqrt{1 / k}(1+i)r}}
# %         {e^{ \sqrt{1 / k}(1+i)a}-e^{-\sqrt{1 / k}(1+i)a}}
# %     +   \frac
# %         {e^{ \sqrt{1 / k}(1-i)r}-e^{-\sqrt{1 / k}(1-i)r}}
# %         {e^{-\sqrt{1 / k}(1-i)a}-e^{ \sqrt{1 / k}(1-i)a}}
# %     \right)
# $$
# This answer is a sum of something and it's complex conjugate (of course, considering how we derived it), and can also be written as
# $$
#     u(r,t) = {3 a \over r} \Re\left\{       e^{ 2i t}
#         \frac
#         {e^{\sqrt{1 / k}(1+i)r}-e^{-\sqrt{1 / k}(1+i)r}}
#         {e^{\sqrt{1 / k}(1+i)a}-e^{-\sqrt{1 / k}(1+i)a}}
#  \right\}
# $$
#
# This can be rewritten as sines/cosines and hyperbolics, but it wouldn't be pretty, so I'll leave it as is.
# <!-- No $\theta$ or $\phi$ dependence in the solution. We transform to the 1D heat equation using
#
# $$
#     u(r,t) \rightarrow w(r,t) = r u(r,t)
# % \\  {T'(t) \over KT(t)} = {R''(r) + {2\over r}R'(r) \over R(r)}
# $$
# which we use to find the Fourier series
# $$
# u()
# $$ -->

# %% [markdown]
# ### 4.1.15

# %% [markdown]
# The $t_0$ shouldn't cause too many problems. In fact, I think we can follow the previous problem quite closely here.
#
# $$
# \\    A_1 \cos(\omega(t-t_0))
#     = {A_1 \over 2} \left( e^{i\omega (t-t_0)} + e^{-i \omega (t-t_0)} \right)
# \\  = {1 \over 2} \left(A_1 e^{i\omega_{1} (t-t_0)} + A_1 e^{i \omega_{-1} (t-t_0)} \right)
#     % = A_1 \left( e^{i\omega t}e^{-i\omega t_0} + e^{-i \omega t}e^{i\omega t_0} \right)
# %\\  \omega_1 = {2\pi \over T} = \omega \rightarrow T = {2\pi \over \omega}
# \\  c_{\pm 1} = \sqrt{\pm {\omega \over 2 K }}
# \\  u(r,t) = {a A_1 \over 2r} \left(
#     e^{ i \omega (t-t_0)} \left( e^{ \sqrt{\omega / 2K}(1+i)r} - e^{- \sqrt{\omega/2K}(1+i)r}
#           \over                  e^{ \sqrt{\omega / 2K}(1+i)a} - e^{- \sqrt{\omega/2K}(1+i)a} \right)
#   + e^{-i \omega (t-t_0)} \left( e^{i\sqrt{\omega / 2K}(1+i)r} - e^{-i\sqrt{\omega/2K}(1+i)r}
#           \over                  e^{i\sqrt{\omega / 2K}(1+i)a} - e^{-i\sqrt{\omega/2K}(1+i)a} \right)
#     \right)
# \\  u(r,t) = {a A_1 \over r} \Re \left\{
# e^{ i \omega (t-t_0)} \left( e^{ \sqrt{\omega / 2K}(1+i)r} - e^{- \sqrt{\omega/2K}(1+i)r}
#       \over                  e^{ \sqrt{\omega / 2K}(1+i)a} - e^{- \sqrt{\omega/2K}(1+i)a} \right) \right\}
# $$
# Really we should have done this problem first and then 4.1.14

# %% [markdown]
# ### 4.1.16

# %% [markdown]
# In the general solution I wrote out above, $\omega_n$ is ${2 \pi \over T} n$, but $\omega = 3$ and $\omega = \pi$ cannot be integer multiples of some $2\pi \over T$. Can we use superposition? The Laplace operator is linear, so we can write
#
# $$
# u(r,t) = u_1(r,t) + u_2(r,t)
# $$
# with
# $$
#     u_1(a,t) = 2\cos(3t)
# \\  u_2(a,t) = 5\cos(\pi t).
# $$
# According to our formula in 4.1.15, this yields
#
# $$
# \\  u_1(r,t) = {2 a \over r} \Re \left\{
# e^{2it      }         \left( e^{ \sqrt{3/ 2K}(1+i)r} - e^{- \sqrt{3/2K}(1+i)r}
#       \over                  e^{ \sqrt{3/ 2K}(1+i)a} - e^{- \sqrt{3/2K}(1+i)a} \right) \right\}
#
# \\  u_2(r,t) = {5 a \over r} \Re \left\{
# e^{ i \pi t }         \left( e^{ \sqrt{\pi / 2K}(1+i)r} - e^{- \sqrt{\pi/2K}(1+i)r}
#       \over                  e^{ \sqrt{\pi / 2K}(1+i)a} - e^{- \sqrt{\pi/2K}(1+i)a} \right) \right\} .
# $$
# The sum of these two solves the heat equation according to linearity.

# %% [markdown]
# ### 4.1.17

# %% [markdown]
# The textbook rewrites the five-stage method in the last part of section 4.1, only with different boundary conditions than this problem. It's recommended to first find $w=ru$, which for one thing simplifies the Poisson Equation problem.
#
# $$
# \\ w_t = Kw_{rr} + \sigma r
# \\ w(a,t) = aT_1
# \\ w(0,t) = 0
# \\ w(r,0) = rT_2
# $$
#
#
# 1. Steady-state (Poisson Equation)
#
# $$
#     KW_{rr} + \sigma r = 0
# \\  W(r) = -{\sigma r^3 \over 6K} + A + Br
# \\  W(0) = 0 \rightarrow A = 0
# \\  W(a) = a T_1 = -{\sigma a^3 \over 6K} + aB
# \\  \rightarrow B = T_1 + {\sigma a^2 \over 6K}
# \\  W(r) = -{\sigma r^3 \over 6K} + \left(T_1 + {\sigma a^2 \over 6K}\right) r
# $$
#
# 2.  Zero bounds transform
#
# $$
# \\  v(r,t) = w(r,t) - W(r)
# \\  \begin{align*}
#     v_t   &= K v_{rr}
# \\  v(0,t)&= 0
# \\  v(a,t)&= 0
# \\  v(r,0)&= {\sigma \over 6K} r^3 + \left(T_2 - T_1 - {\sigma a^2 \over 6K}\right) r
# \end{align*}
# $$
#
# 3. Solve time-dependent component as seperable equation
#
# We actually already have a formula for this Dirichlet inital value problem from chapter 2.
#
# $$
#     v(r,t) = \sum_{n=1}^\infty c_n e^{-K(n\pi/L)^2 t} \sin\left( n \pi r \over a \right)
# \\  c_n = {2\over a} \int_{0}^a \left( {\sigma \over 6K} r^3 + \left(T_2 - T_1 - {\sigma a^2 \over 6K}\right) r \right) \sin\left( n \pi r \over a \right) dr
# $$
#
# I do not know the expansion of $r^3$ in terms of sine.
#
# <!-- $$
#     v(r,t) = R(r)T(t)
# \\  {T'(t) \over K T(t)} = {R''(r) \over R(r)}
# \\  R(r) = A \cosh(\lambda r) + B \sinh(\lambda r)
# \\  T(t) = C \cos (\lambda t) + D \sin (\lambda t)
# \\[1em]
#     v(0,t) = 0 \rightarrow A = 0
# $$ -->

# %%
import sympy as sp
from sympy import pi

r, a = sp.symbols('r a', positive=True)
n = sp.symbols('n', integer=True, positive=True)

sp.simplify((2/a)*sp.integrate(r*r*r*sp.sin(n*pi*r/a), (r,0,a)))
# Out:
# 2*(-1)**n*a**3*(-pi**2*n**2 + 6)/(pi**3*n**3)

# %% [markdown]
# Okay, so with the normalization term $\|\phi_n(r)\|^2 = {2 \over a}$ this gives the expansion of $r$ as
#
# $$
#       {2 \over a} \langle r^3, \phi_n(r) \rangle
#     = (-1)^n \frac{12 a^3 - 2\pi^2 n^2}{\pi^3 n^3}
#     = (-1)^n \left( \frac{12 a^3}{\pi^3 n^3} - \frac{2}{\pi n}\right)
# \\    {2 \over a} \langle r  , \phi_n(r) \rangle
#     = (-1)^{n+1} {2 a \over \pi n}
# $$
# yielding $c_n$ as
#
# $$
#       c_n
#     = {\sigma \over 6K} {2 \over a} \langle r^3, \phi_n(r) \rangle
#     + \left(T_2 - T_1 - {\sigma a^2 \over 6K}\right) {2 \over a} \langle r  , \phi_n(r) \rangle
# \\  = (-1)^{n}  \left(
#       {\sigma \over 6K}
#         \left( \frac{12 a^3}{\pi^3 n^3} - \frac{2}{\pi n}\right)
#     - \left(T_2 - T_1 - {\sigma a^2 \over 6K}\right)
#         {2 a \over \pi n}
#                 \right)
# \\  = (-1)^{n}  \left(
#       \frac{2a^3\sigma}{K \pi^3 n^3}
#     + {2 a (T_1 - T_2) \over \pi n}
#     + {\sigma \left(a^3-1\right) \over 3K \pi n}
#
#                 \right)
# $$
#
# <!-- Before cracking away, note the book gives us a solution to the simpler initial value problem $u_t = K\nabla^2 u$
#
# $$
#     u(r,t) = T_1 + {1 \over r} \sum_{n=1}^\infty B_n \sin {n \pi r \over a} e^{-(n\pi/a)^2Kt}
# \\  B_n = {2 \over a} \int_0^a r[T_2-T_1]\sin{n\pi r \over a} dr
# $$
# So, ideally we'll cite this at some point in the five-stage method.
#
# 1. Steady-state (Poisson Equation)
# $$
#     K\nabla^2 U(r) = K\left(U_{rr} + {2 \over r} U_r \right) = - \sigma
# \\
# $$ -->

# %% [markdown]
# 4. Convert to solution $u(r,t)$
#
# $$
#       w(r,t)
#     = -{\sigma r^3 \over 6K} + \left(T_1 + {\sigma a^2 \over 6K}\right) r + \sum_{n=1}^\infty c_n e^{-K(n\pi/L)^2 t} \sin\left( n \pi r \over a \right)
# \\    u(r,t)
#     = w(r,t)/r
# \\    u(r,t)
#     = -{\sigma r^2 \over 6K} + \left(T_1 + {\sigma a^2 \over 6K}\right)  + {1 \over r} \sum_{n=1}^\infty c_n e^{-K(n\pi/L)^2 t} \sin\left( n \pi r \over a \right)
# $$

# %% [markdown]
# 5. Decay
#
# The first mode $c_1$ is nonzero, so the decay $\tau$ comes from $e^{-K(\pi/L)^2t} = e^{- t / \tau}$
#
# $$
#     % {1 \over \tau} = \frac{K\pi^2}{L^2}
# \\  \tau = {L^2\over K \pi^2}
# $$

# %% [markdown]
# ### 4.3.1

# %% [markdown]
# None of these problems have $\phi$ dependence, allowing us to use the formula in Section 4.3.1
#
# $$
#       u(r,\theta)
#     = \sum_{k=0}^{\infty} B_kr^k P_k(\cos \theta)
# \\    B_k
#     = {k+{1\over 2} \over a^k}
#       \int_{0}^\pi G(\theta) P_k(\cos \theta)\sin \theta d\theta
# \\    G(\theta)
#     = u(a,\theta)
# $$
#
# So, it should be enough to compute $B_k$. I'm not too certain on Legendre functions/polynomial expansions. I believe the first step is to rewrite the $G(\theta)$ in terms of $P_i(\cos \theta)$
#
# $$
# \begin{align*}
#       P_0(\cos \theta)
#    &= 1
# \\    P_1(\cos \theta)
#    &= \cos \theta
# \\    P_2(\cos \theta)
#    &= {3 \over 2}  \cos^2\theta - {1 \over 2}
# \end{align*}
# \\  \cos^2 \theta = {2 \over 3} P_2(\cos \theta) + {1 \over 3} P_0(\cos \theta)
#
# \\  G(\theta)
#     = {10 \over 3}  P_0(\cos\theta)
#     + 4             P_1(\cos\theta)
#     + {2 \over 3}   P_2(\cos\theta)
# $$
#
# Now make use of orthogonality
#
# $$
#       \int_{0}^\pi P_n(\cos \theta) P_k(\cos\theta) \sin \theta d\theta
#     = {2\delta_{nk} \over 2k + 1}
# \\[1em]
#       u(r,\theta)
#     = {10 \over 3}                             P_0(\cos\theta)
#     + 4                  { r \over a }         P_1(\cos\theta)
#     + {2 \over 3}   \left( r \over a \right)^2 P_2(\cos\theta)
# \\
#       u(r,\theta)
#     = {10 \over 3}
#     + 4                  { r \over a }         \cos \theta
#     +               \left( r \over a \right)^2 \left(\cos^2\theta + {1 \over 3} \right)
#
# $$

# %% [markdown]
# ### 4.3.2

# %% [markdown]
# Uhh, Associated Legendre? Actually, it's easier to rewrite the $\cos(2\theta)$.
#
# $$
#       \cos(2\theta)
#     = 2\cos^2 \theta - 1
# \\    u(a,\theta)
#     = 2 \cos^2 \theta
#     = {4 \over 3} P_2(\cos \theta) + {2 \over 3} P_0(\cos \theta)
# \\  u(r, \theta) = {2 \over 3} + {4 \over 3} \left( r \over a\right)^2 P_2 (\cos \theta)
# $$

# %% [markdown]
# ### 4.3.9

# %% [markdown]
# This problem doesn't actually specify what happens at infinity, but in section 4.3.2 we assume $u(r\rightarrow \infty) \rightarrow 0$, so we'll use the appropriate formula.
#
# $$
#       u(r,\theta)
#     = \sum_{k=0}^{\infty} b_k {a^{k+1} \over r^{k+1}}P_k(\cos \theta)
# \\    b_k
#     = {2k+1 \over 2}
#       \int_{0}^\pi G(\theta) P_k(\cos \theta)\sin \theta d\theta
# $$
#
# Which is the same as before, only with $r/a$ flipped and no constant term.
#
# $$
#       \cos^4(\theta)
#     = {1 \over 5} P_0(\cos \theta) + {4 \over 7} P_2(\cos \theta) + {8 \over 35} P_4(\cos \theta)
# \\    G(\theta)
#     = {6 \over 5}   P_0(\cos \theta)
#     + 2             P_1(\cos \theta)
#     + {4 \over 7}   P_2(\cos \theta)
#     + {8 \over 35}  P_4(\cos \theta)
# \\[1em]
#       u(r,\theta)
#     = {6 \over 5}       { a \over r }        P_0(\cos \theta)
#     + 2            \left( a \over r\right)^2 P_1(\cos \theta)
#     + {4 \over 7}  \left( a \over r\right)^3 P_2(\cos \theta)
#     + {8 \over 35} \left( a \over r\right)^4 P_4(\cos \theta)
#
# $$

# %% [markdown]
# ### 4.3.11

# %% [markdown]
# $$
#       G(\theta)
#     = {14 \over 5}  P_1(\cos \theta)
#     + {6 \over 5}   P_3(\cos \theta)
# $$
# Using the same formula from earlier,
# $$
#       {\partial u \over \partial r} (r,\theta)
#     = \sum_{k=0}^{\infty}
#       -(k+1)b_k {a^{k+1} \over r^{k+2}} P_k(\cos \theta)
# \\    {\partial u \over \partial r} (a,\theta)
#     = \sum_{k=0}^{\infty}
#       b_k{ -(k+1)  \over a^{}} P_k(\cos \theta)
# \\  = \sum_{k=0}^{\infty}
#       \tilde{B}_k  P_k(\cos \theta)
# \\  b_k = -{a \over k+1} \tilde{B}_k
# $$
# Easy peasy. Now our normalized expansion returns $\tilde{B}_k$ and we convert to $b_k$ to get our result.
#
# $$
#     \tilde B_1 = {14 \over 5} \rightarrow b_1 = -{7a \over  5}
# \\  \tilde B_3 = { 6 \over 5} \rightarrow b_3 = -{3a \over 10}
# \\  u(r,\theta) = -{7 \over 5} {a^3 \over r^2} P_1(\cos\theta) - {3 \over 10} {a^5 \over r^4} P_3(\cos \theta)
# $$
