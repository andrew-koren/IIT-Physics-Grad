# %% [markdown]
# ## 14.1
#
#
# <br> 1) Show $ 1 = (J_0(x))^2 + 2(J_1(x))^2 + 2(J_2(x))^2 + \dots $
#
# $$
#       g(x,t)g(x,-t)
#     = e^{(x/2)(t-1/t)}e^{(x/2)(-t+1/t)}
#     = \sum_{n=-\infty}^\infty J_n(x)t^n \sum_{m=-\infty}^\infty J_m(x)(-t)^m
# $$

# %% [markdown]
# $$
# g(x,t)g(x,-t) = \exp({x/2(t-1/t)-x/2(t-1/t)})=e^{0}=1
# $$

# %% [markdown]
# $$
# \sum_{n=-\infty}^\infty J_n(x) t^n \sum_{m=-\infty}^\infty J_n(x) (-t)^m = (J_0(x))^2 + \left(
#     \sum_{n=1}^\infty J_{ n}(x)t^{n} + \sum_{n=1}^\infty J_{-n}(x)t^{-n} \right) \left(
#     \sum_{m=1}^\infty J_{-m}(x)t^{m} + \sum_{m=1}^\infty J_{ m}(x)t^{-m} \right)
# \\  = (J_0(x))^2
# \\  + \sum_{n=1}^\infty \sum_{m=1}^\infty J_{ n}(x)J_{ m}(x) t^{ n-m}
# \\  + \sum_{n=1}^\infty \sum_{m=1}^\infty J_{ n}(x)J_{-m}(x) t^{ n+m}
# \\  + \sum_{n=1}^\infty \sum_{m=1}^\infty J_{-n}(x)J_{ m}(x) t^{-n-m}
# \\  + \sum_{n=1}^\infty \sum_{m=1}^\infty J_{-n}(x)J_{-m}(x) t^{-n+m}
# $$

# %% [markdown]
# First, we'll use the wonderful gift that is Eq. 14.5
#
# $$
# \sum_{n=-\infty}^\infty J_n (x) (-t)^n = \sum_{n=-\infty}^\infty (-1)^n J_n(x) (t)^n = \sum_{n=-\infty}^\infty J_{-n}(x) t^n
# $$
# Send $n \rightarrow -n$
# $$
# \sum_{n=-\infty}^\infty J_{-n}(x) t^n = \sum_{n=-\infty}^\infty J_{n}(x) t^{-n}
# $$

# %% [markdown]
# page 650 page 44

# %% [markdown]
# <br> 2)

# %% [markdown]
# <br> 4)
# $$
# \begin{align}
#     J_{n-1}(x) + J_{n+1}(x) &= \frac{2n}{x} J_n(x) \tag{14.7}
# \\  J_{n-1}(x) - J_{n+1}(x) &= 2 J'_n(x) \tag{14.8}
# \end{align}
# $$
#
# 1.  $\quad {d\over dx} [x^{n} J_n (x) ] = x^n J_{n-1}(x)$
#
# Combine the two relations together (and divide by two)
#
# $$
# J_{n-1}(x) = \frac{n}{x} J_n(x) + J'_n(x)
#
# \\  \frac{d}{dx} x^n J_n(x) = nx^{n-1}J_n(x) + x^n J_n'(x)
# \\  = x^n \left(\frac{n}{x} J_n(x) + J_n'(x) \right)
# \\  = x^n J_{n-1}(x)
# $$

# %% [markdown]
# 2.  $\quad {d\over dx} [x^{-n}J_n (x)] = -x^{-n} J_{n+1}(x)$

# %% [markdown]
# Now subtract the two relations instead
#
# $$
# \\  J_{n+1}(x) = \frac{n}{x} J_{n}(x) - J'_{n}(x)
# \\  \frac{d}{dx} x^{-n} J_n(x) = -n x^{-n-1} J_n(x) + x^{-n} J'_n(x)
# \\  = - x^{-n} \left( \frac{n}{x} J_n(x) - J'_n(x) \right)
# \\  = -x^{-n} J_{n+1}(x)
# $$

# %% [markdown]
# 3.  $\quad J_n(x) = J'_{n+1}(x) + \frac{n+1}{x} J_{n+1}$
#
# Same as in 1., just bump the index up
#
# $$
#     \underbrace{J_{n-1}(x) = \frac{n}{x} J_{n}(x) + J'_n(x)}_{n\rightarrow n+1}
# \\[0.5em]  J_{n}(x) = \frac{n+1}{x} J_{n+1}(x) + J'_{n+1}(x)
# $$

# %% [markdown]
# <br> 6)
#
# $$
# \\  \cos(x)= \sum_{k=0}^\infty \frac{(-1)^k}{(2k  )!} x^{2k  }
# \\  \sin(x)= \sum_{k=0}^\infty \frac{(-1)^k}{(2k+1)!} x^{2k+1}
# $$
# We'll just show the RHS as an infinite series becomes these expansions
#
# $$
# \begin{align*}
# \\  J_n(x) &= \sum_{s=0}^\infty \frac{(-1)^s}{s!(n+s)!} \left(x\over 2 \right)^{n+2s}
# \\  (-1)^n J_{2n+1}(x) &= \sum_{s=0}^\infty \frac{(-1)^{n+s}}{s!(2n+1+s)!} \left(x\over 2 \right)^{2n+1+2s}
# \\  2 \sum_{n=0}^\infty (-1)^n J_{2n+1}(x) &= 2 \sum_{n=0}^\infty \sum_{s=0}^\infty \frac{(-1)^{n+s}}{s!(2n+1+s)!} \left(x\over 2 \right)^{2n+1+2s}
# \end{align*}
# $$
# Well, that didn't go according to plan

# %% [markdown]
# <br> 7)
#
# $$
#     g(x,t) = \sum_m J_m(x)t^m
# \\  \frac{\partial g(x,t)}{\partial t}
#     = \sum_m m J_m(x) t^{m-1}
#     = \frac{1}{t} \sum_m m J_m(x) t^{m}
# \\  \begin{align*}
#     J_{n-1}(x) + J_{n+1}(x) &= \frac{2n}{x} J_n(x) \tag{14.7}
# \\  \underbrace{\sum_{n} J_{n-1}(x)t^n}_{n\rightarrow n+1} + \underbrace{\sum_{n} J_{n+1}(x)t^n}_{n\rightarrow n-1} &= \sum_{n} \frac{2n}{x} J_n(x) t^n
# \\  \sum_{n} J_{n}(x)t^{n+1} + \sum_{n} J_{n}(x)t^{n-1} &= \frac{2}{x}\sum_{n} n J_n(x) t^n
# \end{align*}
# \\  \left(1 + \frac{1}{t} \right) g(x,t) = \frac{2t}{x} \frac{\partial g(x,t)}{\partial t}
#
# $$

# %% [markdown]
# <br> 9)

# %% [markdown]
# <br> 10)

# %% [markdown]
# <br> 19)
#
# Apply leibnitz integral rule
#
# $$
# \\  \frac{\partial}{\partial x} J_n(x) = \frac{\partial}{\partial x} \frac{1}{\pi} \int_0^\pi \cos(n\theta - x\sin\theta) d\theta
# \\  J'_n(x) = \frac{1}{\pi} \int_0^\pi \frac{\partial}{\partial x}  \cos(n\theta - x\sin\theta) d\theta
# \\  \frac{\partial}{\partial x}  \cos(n\theta - x\sin\theta) = \sin(n\theta - x \sin \theta) \sin (\theta )
# $$
# Apply trig identity
# $$
# \\  \sin(\alpha)\sin(\beta) = \frac{1}{2}\left[ \cos(\alpha - \beta) - \cos(\alpha + \beta)\right]
# \\  \frac{\partial}{\partial x}  \cos(n\theta - x\sin\theta) = \frac{1}{2} \left[\cos((n-1)\theta - x \sin \theta) - \cos((n+1)\theta - x \sin \theta)\right]
# \\  J'_n(x) = \frac{1}{2} \left[\frac{1}{\pi} \int_0^\pi \cos((n-1)\theta - x\sin\theta) -  \cos((n+1)\theta - x\sin\theta) d\theta \right]
# \\  = \frac{1}{2} \left[ J_{n-1}(x) - J_{n+1}(x) \right]
# $$

# %% [markdown]
# ## 14.5
#
# <br> 1)
# <br> 2)
# <br> 6)
# <br> 7)
# <br> 14)
# <br> 15)
