# %% [markdown]
# Homework # 4
#
#
# 1. Use the second quantization formalism to calculate the first order non-linear correction to one-dimensional harmonic oscillator energy levels if the non-linear term is $\hat{\mathcal{H}}_I = \lambda {\hat p}^4 / 4$.
#
# 2. Now use the second quantization formalism to calculate the SECOND order non-linear corrections to
# one-dimensional harmonic oscillator energy levels if the non-linear term is $\hat{\mathcal{H}}_I = \lambda {\hat x}^3 / 3$. The first order
# correction is equal to zero (prove it).
#
# 3. Calculate energy levels of a two-dimensional isotropic oscillator with the Hamiltonian of
# $$ \hat H(𝑥,𝑦)= \frac{1}{2𝑚} (𝑝̂_𝑥2 + 𝑝̂_𝑦2) +\frac{1}{2}𝑘 (𝑥̂2 +𝑦̂2) +𝛼𝑥̂𝑦̂
# $$
# Consider the case of $|𝛼|<𝑘$. What happens if $|𝛼|>𝑘$ ?
# Hints: Diagonalize the potential energy quadratic form. Double check that the Laplace operator from the kinetic energy term is still diagonal in new coordinates. Now, you have a sum of two independent one-dimensional harmonic oscillators.
#
# 4. For the oscillator from the previous problem find the first order correction of the ground energy level treating the term $𝑉 =𝛼𝑥̂𝑦̂$ as a perturbation.
#
# 5. Now, for the same model calculate the first order corrections of a) the first b) the second excited energy levels. Find correct zero order eigenfunctions. Hint: you will need to figure out the degeneracy, matrix elements of the perturbation, and finally solve a secular equation.
#
# 6. An external homogeneous time-dependent electric field $Ɛ(𝑡)=Ɛ_0 e^{−𝑡^2/𝜏^2}\cos 𝜔_0𝑡 $ is applied on a one-dimensional charged harmonic oscillator. If for $t→−∞$ the oscillator is at the $𝑛^{th}$ energy level, what
# is the probability of its transition to the other energy levels (which ones?) when $𝑡 →+∞$?
#
# 7. A time-dependent periodic perturbation of $\hat V(𝑥,𝑡)=−𝑥̂𝐹_0 \cos𝜔_0𝑡$ is applied on a particle in a $δ$-well. In the first perturbation order, calculate a probability per time unit of the particle transition to the continuous spectrum (sort of ionization). Hint: The Golden Fermi Rule is applicable here.
