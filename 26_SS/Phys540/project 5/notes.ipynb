# %% [markdown]
# straight
#
# ```g4beamline
# param loopoffset = $straight*...
#
# place qf  z=3*$loopoffset+$lcell*($i-1) x = 0
# place pipe z=3*$loopoffset+5e3+$lcell*($i-1) x = 0
# place qd z=3*$loopoffset+10e3+$lcell*($i-1) x = 0
# place pipe z=3*$loopoffset+15e3+$lcell*($i-1) x = 0
# ```
#
# ring_final_sbend has the corner arcs.
# 1. Use half ring.
#     n = 20 -> 10 turns
# 2. Add in straight section
# 3. Repeat half ring loop (11 20)
#     -   `param offset=16*$lcell`
#     -   `place qf z=$offset+$lcell*($i-1) x=0` ...
# 4.
#
# bonus: see if arcs with quads pi/2 phase advance, try adding ds correction

# %% [markdown]
# do i 1 $straight 2
# place qf
