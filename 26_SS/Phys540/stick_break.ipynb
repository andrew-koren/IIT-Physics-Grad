# %% [markdown]
# Angle is flipped for each side. Same sign means same side
# Set middle segment left side to $x = 0$, right side is $x = L_m$, then the sides will cross if $

# %%
import numpy as np

break_locations = np.random.rand(2)
angles = (np.random.rand(2) - 0.5)*2*np.pi

tringle = 2
while True:
    if np.any(break_locations>0.5): # too short to consider
        tringle = 0
        break
    if angles[0] * angles[1] < 0: # facing opposite directions
        tringle = 0
        break
    L_L = break_locations.min()
    L_R = 1-break_locations.max()
    L_M = break_locations.max()-break_locations.min()
    print(L_L * np.cos(angles[0]))
    print(L_R * np.cos(angles[1]))
    break
# Out:
# 0.015863979674778608
# 0.7297624507459455
