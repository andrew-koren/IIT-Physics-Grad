# %% [markdown]
# We are studying free complex scalar fields $\phi = \phi_1 + i\phi_2$ which exhibit $U(1)$ global phase symmetry, i.e. we can multiply by an arbitrary phase factor $e^{i\theta}$. We'll start from classical mechanics and work our way to quantization. The Lagrangian for the system is
#
# $$
# \def\l{\left}\def\r{\right}
# \def\c#1#2{\l[#1,#2\r]}
# \def\ac#1#2{\l\{#1,#2\r\}}
# \def\d#1#2{\frac{\partial #1}{\partial #2}}
# \def\sq{\square}
# \def\p{\partial}
# \def\L{\mathcal L}
# $$
#
# $$
# \L = {1 \over 2} \p_\mu \phi^* \p^\mu \phi - {1 \over 2} m^2 \phi^* \phi.
# $$
# We would like to derive the Euler-Lagrange equations via least action principle. The action is $S = \int \L d^4 x$. This should collapse to Klein-Gordon-Fock for a special case
#
# $$
# \sq \phi + m^2 \phi = 0.
# $$
#
# Note we're using the minkowski metric from class with diagonal $(1,-1,-1,-1)$, and we use shorthand $\p_\mu = {\p \over \p x^\mu}$. Also note $g^{\mu \nu} = g_{\mu \nu}$.
#
# $$
# \begin{align*}
#         \delta S
#    &= \int d^4 x\ \delta\left(
#           {1 \over 2} \p_\mu \phi^* \p^\mu \phi
#         - {1 \over 2} m^2 \phi^* \phi
#       \right),
# \\ &= \int d^4 x\ \left[ \delta\left(
#           {1 \over 2} \p_\mu \phi^* \p^\mu \phi
#       \right)
#     - \delta \left(
#           {1 \over 2} m^2 \phi^* \phi
#         \right) \right],
# \\ &= {1\over 2}\int d^4 x\ \left[
#           \p_\mu \delta \phi^* \p^\mu \phi
#         + \p_\mu \phi^* \p^\mu \delta \phi
#
#         - m^2 \delta \phi^* \phi
#         - m^2 \phi^* \delta \phi
#         \right].
#
# \end{align*}
# $$
# Apply stokes theorem for manifolds to reorder $\delta \phi$
#
# $$
# \begin{gathered}
#       \int \p_\mu \phi^* \p^\mu \delta \phi   d^4 x
#     = \int \p^\mu (\p_\mu \phi^* \delta \phi) d^4 x
#     - \int (\p^\mu \p_\mu \phi^*) \delta \phi d^4 x,
# \\  = \oint \p^\mu \phi^* \delta \phi d^3 x
#     - \int \p^\mu \p_\mu \phi^* \delta \phi   d^4 x
#     = 0 - \int \p^\mu \p_\mu \phi^* \delta \phi   d^4 x,
# \\ \vdots
# \\      \delta S
#     = {1\over 2}\int d^4 x\ \left[
#         - \delta \phi^* \sq \phi
#         - \sq \phi^* \delta \phi
#
#         - m^2 \delta \phi^* \phi
#         - m^2 \phi^* \delta \phi
#         \right].
# \end{gathered}
# $$
#
# We're free to set $\delta \phi = 0$, yielding
#
# $$
# \begin{gathered}
# \delta S = -{1 \over 2} \int d^4 x\ \delta \phi^* \left[\sq \phi + m^2 \phi \right] = 0,
# \\  \sq \phi + m^2 \phi = 0,
# \end{gathered}
# $$
# with the other Euler-Lagrange equation being the same, conjugated.

# %% [markdown]
# Energy can be found from the Hamiltonian, which can be made from the Lagrangian as
# $$
# \def\l{\left}\def\r{\right}
# \def\c#1#2{\l[#1,#2\r]}
# \def\ac#1#2{\l\{#1,#2\r\}}
# \def\d#1#2{\frac{\partial #1}{\partial #2}}
# \def\sq{\square}
# \def\p{\partial}
# \def\L{\mathcal L}
# $$
#
# $$
# H = \d{\L}{\dot{q}^i}\dot{q}^i - \L
# $$
# or, in our case
# $$
# \begin{align*}
#     H &= \d{\L}{(\p_0 \phi^i)} \p^0 \phi^i - \L,
# \\    &= \d{}{(\p_0 \phi^i)}\l[{1 \over 2} \p_\mu \phi^* g^{\mu\nu} \partial_{\mu} \phi \r] \p^0 \phi^i
#        - {1 \over 2} \p_\mu \phi^* \p^\mu \phi + {1 \over 2} m^2 \phi^* \phi.
# \end{align*}
# $$
# where $\phi^0 = \phi$, $\phi^1 = \phi^*$. I don't think we can get much further without splitting up space and time. Using $\dot \phi = \d{\phi}{t}$, the mostly-negative metric gives us
#
# $$
# \begin{align*}
# H  &= \d{}{\dot \phi  } \l[ {1 \over 2} \dot \phi^* \dot \phi + c\r] \left( \dot{\phi} \right)
#     + \d{}{\dot \phi^*} \l[ {1 \over 2} \dot \phi^* \dot \phi + c\r] \dot{\phi}^*
#     - {1 \over 2} \p_\mu \phi^* \p^\mu \phi + {1 \over 2} m^2 \phi^* \phi,
# \\ &= { 1\over 2} \left[
#           \dot \phi^* \dot \phi
#         + \dot \phi \dot \phi^*
#         - \l[\dot \phi^* \dot \phi - \nabla \phi^* \cdot \nabla \phi \r]
#         + m^2 |\phi|^2
#     \right],
# \\ &= { 1\over 2} \left[
#       \dot \phi \dot \phi^*
#     + \nabla \phi^* \cdot \nabla \phi
#     + m^2 |\phi|^2
#     \right],
# \\ &= { 1\over 2} \left[
#       \l|\dot \phi\r|^2
#     + \l|\nabla \phi\r|^2
#     + m^2 |\phi|^2
#     \right].
# \\E&= \int H d^3 x
#
#
# % \\ &= { 1\over 2} \left[
# %           \dot \phi^* \dot \phi
# %         - \nabla \phi^* \dot \phi
# %         + \dot \phi^* \dot \phi
# %         - \dot \phi^* \nabla \phi
# %         - \l[\dot \phi^* - \nabla \phi^*\r] \l[\dot \phi - \nabla \phi\r]
# %         + m^2 |\phi|^2
# %     \right],
# % \\ &= { 1\over 2} \left[
# %           2|\dot \phi|^2
# %         - \nabla \phi^* \dot \phi
# %         - \dot \phi^* \nabla \phi
# %         - \l[
# %               |\dot \phi|^2
# %             - \nabla \phi^* \dot \phi
# %             - \dot \phi^* \nabla \phi
# %             + \nabla \phi^* \nabla \phi
# %         \r]
# %         + m^2 |\phi|^2
# %     \right],
# % \\ &= { 1\over 2} \left[
# %           |\dot \phi|^2
# %         - |\nabla \phi|^2
# %         + m^2 |\phi|^2
# %     \right].
# \end{align*}
# $$
# Nice. Noether's theorem for the symmetry $\phi \rightarrow e^{-i\alpha}\phi$ predicts conservation of charge, with $\delta \phi$ as
#
# $$
# \begin{gathered}
#     \phi \rightarrow \l(1 - i\alpha - {\alpha^2 \over 2} + \dots\r) \phi
#    \approx (1-i\alpha) \phi,
# \\ \phi + \delta \phi = \phi -i \alpha \phi,
# \\ \delta \phi = \alpha (-i \phi),
# \quad
#    \delta \phi^* = \alpha (i \phi^*).
# \end{gathered}
# $$
# This transformation leaves $\L$ unchanged, so we expect $\L \rightarrow \L + \delta \L$ to have $\delta \L = 0$.
# $$
# \begin{align*}
#       \delta \L
#    &= \delta \l({1 \over 2} \p_\mu \phi^* \p^\mu \phi - {1 \over 2} m^2 \phi^* \phi \r),
# \\ &= {1 \over 2} \l[
#           \delta\l(\p_\mu \phi^* \p^\mu \phi \r)
#         - \delta\l(m^2 \phi^* \phi \r)
#          \r],
# \\ &= {1 \over 2} \l[
#           (\delta\p_\mu \phi^*) \p^\mu \phi
#         + \p_\mu \phi^* (\delta \p^\mu \phi)
#         - m^2 (\delta \phi^*) \phi
#         - m^2 \phi^* (\delta \phi)
#          \r],
# \\ &= {1 \over 2} \l[
#           \p_\mu \delta \phi^* \p^\mu \phi
#         + \p_\mu \phi^* \p^\mu \delta \phi
#         - m^2 \delta \phi^* \phi
#         - m^2 \phi^* \delta \phi
#         \r].
# \end{align*}
# $$
#
# From here, expanding out each $\delta$ term will result in $\delta \L = 0$
#
# $$
# \begin{align*}
#         \delta \L
#    &= {1 \over 2} \l[
#           \p_\mu (\alpha i\phi^*) \p^\mu \phi
#         + \p_\mu \phi^* \p^\mu (-\alpha i\phi)
#         - m^2 (\alpha i\phi^*) \phi
#         - m^2 \phi^* (-\alpha i\phi)
#         \r],
# \\ &= {1 \over 2} \l[
#        (  \alpha i \p_\mu \phi^* \p^\mu \phi
#         - \alpha i \p_\mu \phi^* \p^\mu \phi )
#         +(\alpha i m^2 \phi^* \phi
#         - \alpha i m^2 \phi^* \phi)
#         \r],
# \\ &= 0.
#
# \end{align*}
# $$

# %% [markdown]
# However, we can use the product rule,
#
# $$
# \begin{align*}
#       \p_\mu \delta \phi^* \p^\mu \phi
#    &= \p^\mu \l(\p_\mu \delta \phi^* \phi \r)
#     - \l(\p^\mu \p_\mu \delta \phi^* \r) \phi,
# \\    \p_\mu \phi^* \p^\mu \delta \phi
#     = \p^\mu \phi^* \p_\mu \delta \phi
#    &= \p^\mu \l( \phi^* \p_\mu \delta \phi \r)
#     - \phi^* \l( \p^\mu \p_\mu \delta \phi \r),
# \end{align*}
# $$
# to rewrite $\delta L$ as (dropping the $1/2$ for brevity since $\delta L = 0$)
#
# $$
# \begin{align*}
#       \p \L
#    &= \p^\mu \l(\p_\mu \delta \phi^* \phi \r)
#     - \l(\p^\mu \p_\mu \delta \phi^* \r) \phi
#     + \p^\mu \l( \phi^* \p_\mu \delta \phi \r)
#     - \phi^* \l( \p^\mu \p_\mu \delta \phi \r)
#     - m^2 \delta \phi^* \phi
#     - m^2 \phi^* \delta \phi,
# \\ &= \p^\mu \l(
#           \p_\mu \delta \phi^* \phi
#         + \phi^* \p_\mu \delta \phi
#     \r)
#     - i \alpha \sq \phi^* \phi
#     + i \alpha \phi^* \sq \phi
#     - i \alpha m^2 \phi^* \phi
#     + i \alpha m^2 \phi^* \phi,
# \\ &= \p^\mu \l(
#           \p_\mu \delta \phi^* \phi
#         + \phi^* \p_\mu \delta \phi
#     \r)
#     - i \alpha \phi   \l(\sq \phi^* + m^2 \phi^*\r)
#     + i \alpha \phi^* \l(\sq \phi   + m^2 \phi  \r),
# \end{align*}
# $$
# which reveals two copies of Klein-Gordon = 0. Integrating the remaining term for each $\mu$ yields
# $$
# \begin{align*}
#       j_\mu
#    &= \p_\mu \delta \phi^* \phi
#     + \phi^* \p_\mu \delta \phi,
#
# \\ &= i\alpha \left( \phi \p_\mu \phi^*
#     - \phi^* \p_\mu \phi \right),
# \end{align*}
# $$
#
# where $j_\mu$ is a constant that is coincidentally current when $\alpha = -1$. $j_0$ is then
#
# $$
# j_0 = \phi^* \dot \phi - \phi \dot \phi^*.
# $$
# To verify charge is invariant, we'll just show $\delta Q = 0$:

# %% [markdown]
# $$
# \begin{align*}
# \delta Q   &= \int \delta j_0 d^3 x,
# \\         &= \int \delta \l( \phi^* \p_0 \phi - \phi \p_0 \phi^*\r) d^3 x,
# \\         &= \int \l(
#       \delta \phi^* \p_0 \phi
#       \phi^* \p_0 \delta \phi
#     - \delta \phi \p_0 \phi^*
#     - \phi \p_0 \delta \phi^*
#     \r) d^3 x,
# \\         &= \int \l(
#       i \alpha \l(\phi^* \p_0 \phi
#     -             \phi^* \p_0 \phi  \r)
#     + i \alpha \l( \phi \p_0 \phi^*
#     -              \phi \p_0 \phi^*\r)
#     \r) d^3 x,
# \\ &= 0.
#
# \end{align*}
# $$

# %% [markdown]
# For our next phase of this homework, we have to define $\tilde \phi$ ourselves in a way which gets us from 4D to 3D. We'll pull out the identity $k^0 = \sqrt{\vec k ^2 + m^2}$ from a dirac-delta. The Klein-Gordon-Fock equation reveal we can write $\phi \sim e^{ikx}$, so the $k$-space version of the equation becomes
#
# $$
# \l(-k^2 + m^2 \r) \tilde \phi(k) = 0,
# $$
# which is true under integration when $\phi \sim \delta(k^2-m^2)$. This yields the fourier transform as
#
# $$
# \begin{gathered}
#     \tilde \phi(k) = A(k) \delta(k^2 - m^2),
# \\  \phi(x)  =\int e^{ikx} A  (k) \delta(k^2-m^2) {d^4 k \over (2\pi)^{3/2}},
# \\  \phi^*(x)=\int e^{ikx} A_*(k) \delta(k^2-m^2) {d^4 k \over (2\pi)^{3/2}}.
# \\
# \end{gathered}
# $$
# Integrating over the time dimension yields
# $$
# \begin{gathered}
#     k^2 = k_\mu k^\mu = (k^0)^2 - \vec k ^ 2,
# % \\  \delta(k^2 - m^2)
# % \rightarrow
# \\ \begin{align*}
#       \phi(x)
#    &= \int e^{ikx},
#       A\l(k\r)
#       \delta \l((k^0)^2-(\vec k^2 + m^2)\r)
#       {d^4 k \over (2\pi)^{3/2}},
# \\ &= \int e^{ikx}
#       A\l(k\r)
#       \l(
#           \delta\l(k^0 - \sqrt{\vec k^2 + m^2}\r)
#         + \delta\l(k^0 + \sqrt{\vec k^2 + m^2}\r)
#       \over 2 k^0 \r)
#       {d^4 k \over (2\pi)^{3/2}},
# \\ &= \int \left(
#           e^{ik'x}    A ( \vec k')
#         + e^{i(-k')x} A (-\vec k') \over \sqrt{2k^0}\r)
#         {d^3 k \over (2\pi)^{3/2} \sqrt{2k^0}},
# \end{align*}
# % \\  \phi^*(x)=\int e^{ikx} A_*(k) \delta(k^2-m^2) {d^4 k \over (2\pi)^{3/2}}.
# \end{gathered}
# $$
# where $\pm k'$ has $k^0 = \pm \sqrt{\vec k^2 + m^2}$ and the same values as $k$ for the other dimensions. This splits into our result
# $$
# \begin{gathered}
#     \phi^{\pm} (x) = \int \phi^\pm (k') e^{\pm ik'x}{d^3 k' \over (2\pi)^{3/2} \sqrt{2k^0}},
# \\  \phi^\pm(k) = { A(\pm k) \over \sqrt{2k^0}},
# \\  \phi(x) = \phi^+(x) + \phi^-(x).
# \end{gathered}
# $$
# We switch from $i(-k')x$ to $-ik'x$ since we integrate over all of 3D $k$-space anyways. Solving for $\phi_*^\pm$ follows the exact same steps.
#
# $$
# \begin{gathered}
#       \phi^*(x)
#     = \int e^{ikx} A_*(k) \delta(k^2 - m^2) {d^4 k \over (2\pi)^{3/2}}
#     = \dots
# \\  \phi_*^{\pm} (x) = \int \phi_*^\pm (k') e^{\pm ik'x}{d^3 k' \over (2\pi)^{3/2} \sqrt{2k^0}},
# \\  \phi^*(x) = \phi_*^+(x) + \phi_*^-(x),
# \\ \phi_*^\pm (k) = {A_*(\pm k) \over \sqrt{2k^0}}.
# \end{gathered}
# $$
#
# How is $A_*$ related to $A$? To make the fourier transform of $(\phi(x))^*$ match the above equations, we'd send $e^{ikx}\rightarrow e^{-ikx}$, so we expect to have $\phi_*^{\pm}(k)=\phi^{\mp}(-k)$ to match the signs up again after flipping the three $\vec k$ coordinates.
#
# <!-- note that $\phi \sim e^{-ikx}$ (implied by Noether ideas and $k^0 = \sqrt{\vec{k}^2+m^2}$). This means we can write the Klein-Gordon-Fock equation in $k$-space as
#
# $$
# \begin{gathered}
#     \p_\mu \rightarrow -ik_\mu
# \\  \l(k^2 + m^2\r)\tilde \phi = 0
# \end{gathered}
# $$ -->

# %% [markdown]
# $$
# \begin{gathered}
# \begin{align*}
#       \l(\phi(x)\r)^*
#    &= \l(
#         \int \left(
#           e^{ik'x}    A ( \vec k')
#         + e^{i(-k')x} A (-\vec k') \over \sqrt{2k^0}\r)
#         {d^3 k \over (2\pi)^{3/2} \sqrt{2k^0}}
#     \r)^*
# \\ &= \int \left(
#           e^{-ik'x} A^* ( \vec k')
#         + e^{ ik'x} A^* (-\vec k') \over \sqrt{2k^0}\r)
#     {d^3 k \over (2\pi)^{3/2} \sqrt{2k^0}}
# \\    \phi^*(x)
#     = \l(\phi(x)\r)^*
#    &= \int \left(
#           e^{ ik'x} A_* ( \vec k')
#         + e^{-ik'x} A_* (-\vec k') \over \sqrt{2k^0}\r)
#         {d^3 k \over (2\pi)^{3/2} \sqrt{2k^0}}
# \end{align*}
# \\ A_* (-\vec k') = A^*( \vec k') \rightarrow \phi_*^-(k) = \l(\phi^{+}(k) \r)^*
# \\ A_* ( \vec k') = A^*(-\vec k') \rightarrow \phi_*^+(k) = \l(\phi^{-}(k) \r)^*
# \end{gathered}
# $$

# %% [markdown]
# Now we can start working on $E$ and $Q$.
#
# $$
# \def\l{\left}\def\r{\right}
# \def\c#1#2{\l[#1,#2\r]}
# \def\ac#1#2{\l\{#1,#2\r\}}
# \def\d#1#2{\frac{\partial #1}{\partial #2}}
# \def\sq{\square}
# \def\p{\partial}
# \def\L{\mathcal L}
# $$
#
#
# $$
# \begin{align*}
#       E
#    &= \int {1 \over 2} \l[
#       \dot \phi(x) \dot \phi^*(x)
#     + \vec \nabla \phi(x) \cdot \vec \nabla \phi^*(x)
#     + m^2 \phi^*(x) \phi(x)
# \r] d^3 x,
# % \\ &= {1 \over 2} \l[
# %       2 \p_0 \phi(x) \p_0 \phi^*(x)
# %     - \p_\mu \phi(x) \p^\mu \phi^*(x)
# %     + m^2 \phi^*(x) \phi(x)
# % \r]
# \\    Q
#    &= \int d^3 x
#       \l(
#         \phi^*(x) \p_0 \phi(x) - \phi(x) \p_0 \phi^*(x)
#       \r).
# \end{align*}
# $$
#
# <!-- First, let's note that $ \int e^{ikx} d^3 k = (2\pi)^3 \delta^{3}(x)$.  -->
#
# First, lets find all the derivatives and products we'll need.
#
# $$
# \begin{gathered}
#       \dot \phi(x)
#     = \int i{d^3 k \sqrt{k^0} \over (2\pi)^{3/2}\sqrt{2}}
#     \l(e^{ik'x}\phi^+(k')-e^{-ik'x}\phi^-(k')\r)
#     = i k^0 \l(\phi^+(x) - \phi^-(x)\r),
# \\    \dot \phi^*(x)
#     = \int i{d^3 k \sqrt{k^0} \over (2\pi)^{3/2}\sqrt{2}}
#     \l(e^{ik'x}\phi_*^+(k')-e^{-ik'x}\phi_*^-(k')\r)
#     = i k^0 \l(\phi_*^+(x) - \phi_*^-(x)\r),
# \\
#     \vec \nabla \phi(x)
#     = \int i\vec k {d^3 k \over (2\pi)^{3/2}\sqrt{2k^0}}
#     \l(e^{ik'x}\phi^+(k')-e^{-ik'x}\phi^-(k')\r),
#     % = i \vec k \l(\phi_*^+(x) - \phi_*^-(x)\r),
# \\
#     \vec \nabla \phi^*(x)
#     = \int i\vec k {d^3 k \over (2\pi)^{3/2}\sqrt{2k^0}}
#     \l(e^{ik'x}\phi_*^+(k')-e^{-ik'x}\phi_*^-(k')\r).
#
# \end{gathered}
# $$
# The products of these are then (using $k'\rightarrow k$ to distinguish the two integrals)
#
# $$
# \begin{gathered}
#       \dot \phi(x) \dot \phi^*(x)
#     = -{1 \over 2 (2\pi)^{3}} \int \sqrt{k^0 {k^0}'} d^3 k d^3 k'\
#         \l(e^{ik x}\phi^  +(k )-e^{-ik x}\phi^-  (k )\r)
#         \l(e^{ik'x}\phi_*^+(k')-e^{-ik'x}\phi_*^-(k')\r),
# \\  = -{1 \over 2 (2\pi)^{3}} \int \sqrt{k^0 {k^0}'} d^3 k d^3 k'\
#         \l\{ \begin{align*}
#              e^{i(k+k' )x}&\phi^+(k)\phi_*^+(k')
#         \\  -e^{i(k-k' )x}&\phi^+(k)\phi_*^-(k')
#         \\  -e^{i(k'-k )x}&\phi^-(k)\phi_*^+(k')
#         \\  +e^{i(-k-k')x}&\phi^-(k)\phi_*^-(k') \end{align*}
#         \r\}.
# \end{gathered}
# $$
#
#
#
# While we can't use the identity $ \int e^{ikx} d^3 k = (2\pi)^3 \delta^{3}(x)$ with the function $\phi(k)$ in the integral, we can do $\int A(\vec k) e^{ikx} d^3 x = (2\pi)^3 A(\vec k) \delta^{3}(k)$
#
# $$
# \begin{gathered}
# \int \dot \phi(x) \dot \phi^*(x) d^3 x
#     = -{1 \over 2} \int \sqrt{k^0 {k^0}'} d^3 k d^3 k'\
#         \l\{\begin{align*}
#              \delta(k+k' )&\phi^+(k)\phi_*^+(k')
#         \\  -\delta(k-k' )&\phi^+(k)\phi_*^-(k')
#         \\  -\delta(k'-k )&\phi^-(k)\phi_*^+(k')
#         \\  +\delta(-k-k')&\phi^-(k)\phi_*^-(k')
#             \end{align*}
#         \r\},
# \\  = -{k^0 \over 2} \int  d^3 k \
#         \l\{
#             \phi^+(k)\phi_*^+(-k)
#         \\  -\phi^+(k)\phi_*^-(k)
#         \\  -\phi^-(k)\phi_*^+(k)
#         \\  +\phi^-(k)\phi_*^-(-k)
#
#         \r\}.
# \end{gathered}
# $$
# Similarly for the other two we have
# $$
# \begin{gathered}
#       \int \vec \nabla \phi(x) \cdot \vec \nabla \phi^*(x) d^3 x
#     = -{1 \over 2} \int d^3k\
#         \vec k \cdot
#             \l\{\begin{align*}
#                  \delta(k+k' )&\vec k' \phi^+(k)\phi_*^+(k')
#             \\  -\delta(k-k' )&\vec k' \phi^+(k)\phi_*^-(k')
#             \\  -\delta(k'-k )&\vec k' \phi^-(k)\phi_*^+(k')
#             \\  +\delta(-k-k')&\vec k' \phi^-(k)\phi_*^-(k')
#                 \end{align*}
#             \r\},
# \\  = {1 \over 2} \int d^3k\
#         k^2
#         \l\{
#              \phi^+(k)\phi_*^+(-k)
#         \\  +\phi^+(k)\phi_*^-(k)
#         \\  +\phi^-(k)\phi_*^+(k)
#         \\  +\phi^-(k)\phi_*^-(-k)
#         \r\},
# \\    \int m^2 \phi(x) \phi^*(x) d^3 x
#             = {m^2 \over 2} \int d^3k\
#
#                     \l\{\begin{align*}
#                          \delta(k+k' )&\phi^+(k)\phi_*^+(k')
#                     \\  +\delta(k-k' )&\phi^+(k)\phi_*^-(k')
#                     \\  +\delta(k'-k )&\phi^-(k)\phi_*^+(k')
#                     \\  +\delta(-k-k')&\phi^-(k)\phi_*^-(k')
#                         \end{align*}
#                     \r\},
# \\  = {m^2 \over 2} \int d^3k\
#         \l\{
#              \phi^+(k)\phi_*^+(-k)
#         \\  +\phi^+(k)\phi_*^-(k)
#         \\  +\phi^-(k)\phi_*^+(k)
#         \\  +\phi^-(k)\phi_*^-(-k)
#         \r\}.
# \end{gathered}
# $$
#
# Lastly we'll need $\phi^* \dot \phi$ and $\phi \dot \phi^*$ to wrap things up
#
# $$
# \begin{align*}
#       \phi^*(x) \dot \phi(x)
#    &= i k^0 \l(\phi_*^+(x) + \phi_*^-(x) \r) \l(\phi^+(x) - \phi^-(x)\r),
# \\ &= i k^0 \l(   \phi^+(x)\phi_*^+(x)
#                 - \phi^-(x)\phi_*^+(x)
#                 + \phi^+(x)\phi_*^-(x)
#                 - \phi^-(x)\phi_*^-(x) \r)
#
# \\    \phi(x) \dot \phi^*(x)
#    &= i k^0 \l(\phi^+(x) + \phi^-(x)\r) \l(\phi_*^+(x) - \phi_*^-(x) \r)
# \\ &= i k^0 \l(   \phi^+(x)\phi_*^+(x)
#                 - \phi^+(x)\phi_*^-(x)
#                 + \phi^-(x)\phi_*^+(x)
#                 - \phi^-(x)\phi_*^-(x) \r)
# \end{align*}
# $$
#
# Unfortunately, I don't have time to collapse these down to $E$ and $Q$, but it should all cancel out and become the formulas provided in the problem.

# %% [markdown]
# ---
#
# Switching to quantum mechanics, we'll promote to $\hat \phi (k)$ and conjugate momentum $\hat \pi(k)$

# %% [markdown]
# $$
# \begin{gathered}
# \hat \L(x) = {1 \over 2} \p_\mu \hat \phi^*(x) \p^\mu \hat \phi(x)
#         - {1 \over 2} m^2 \hat \phi^*(x) \hat \phi(x)
#
# \\ \hat \pi^i(x) = \d{\hat \L}{\dot \phi^i(x)}
# \\ \hat \pi  (x) = {1 \over 2}\d{\hat \phi^*(x)}{t}
# \quad
#    \hat \pi^*(x) = {1 \over 2}\d{\hat \phi(x)}{t}
# \end{gathered}
# $$
#
# What about $\hat \pi(k)$? Without doing too much work, we do have $\dot {\hat \pi}(k)$
#
# $$
# \begin{gathered}
# \hat H(k) = k^0 \l\{ \hat \phi_*^+(\vec k) \hat \phi^-(\vec k) + \hat \phi^+(\vec k)\hat \phi_*^-(\vec k)\r\}
# \\  {d \hat \pi^\pm(\vec k) \over dt} = -\d{\hat H(\vec k)}{\phi^\pm}
# \\  {d \hat \pi^+  (\vec k) \over dt} = - k^0 \hat \phi_*^- (\vec k)
# \quad
#     {d \hat \pi^-  (\vec k) \over dt} = - k^0 \hat \phi_*^+ (\vec k)
# \end{gathered}
# $$
# since we have $\phi(k) \sim e^{ikx}$, we expect $\pi(k) \sim e^{ikx}$, so $\dot{\pi}^{\pm} \sim \pm ik^0 \pi$, yielding
# $$
# \begin{gathered}
#     \hat \pi^\pm(\vec k) = \pm i\hat \phi_* (\vec k)
# \\
# \end{gathered}
# $$
