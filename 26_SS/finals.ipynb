# %% [markdown]
# Project
# - Toy model                         soon        Done!
# - Writeup                           soon        Done!
#
#
# - 510 Final project / presentation  4/20 - 4/29 00%
# - 540 Final Presentation            4/28 - 4/30 00%
# - 510 Take home exam                4/29        00%
#
# - 505 Hw 1-7                        4/29        60%
# - 510 HW6                           4/29        Done!
# - 540 HW5                           4/30        00%
# - 505 Final project / presentation  ends:  5/5  00%
# - 685 Referee #2                    5/07        00%
