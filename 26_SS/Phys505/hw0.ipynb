# %% [markdown]
# Phys 505 - HW0
#
# Andrew Koren

# %% [markdown]
# <br> (a) in rectangular (Cartesian) coordinates (x, y, z)
# <br> • x = 1
# An infinite plane in the yz coordinates located at $x-1$
# <br> • x = y = 1
# An infinite line in the z-coordinate passing through the x,y point (1,1)
# <br> • x = y = z = 1
# A point located at (1,1,1)
# <br> • x = y
# <br> • x = y = z
# <br> • x2 + y2 = 1
# <br> • √x2 + y2 = z
# <br> • x2 + y2 = z2
# <br> • √x2 + y2 = |z|
# <br> (b) in spherical coordinates (r, θ, φ)
# <br> • r = 1
# <br> • θ = 1
# <br> • φ = 1
# <br> • r = θ = 1
# <br> • r = φ = 1
# <br> • θ = φ = 1
# <br> (c) in cylindrical coordinates (ρ, φ, z)
# <br> • ρ = 1
# <br> • φ = 1
# <br> • z = 1
# <br> • ρ = φ = 1
# <br> • ρ = z = 1
# <br> • φ = z = 1
# <br> • ρ = φ = z = 1
